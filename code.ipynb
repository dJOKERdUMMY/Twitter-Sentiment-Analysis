# %%
#import pandas
import pandas as pd
#read the csv training file
train = pd.read_csv("train_E6oV3lV.csv",index_col="id")
#exploratory data analysis
print("Dataframe shape:",train.shape)
print("Columns:",train.columns.values)
print(train.head())
# Out:
# Dataframe shape: (31962, 2)
# Columns: ['label' 'tweet']
#     label                                              tweet
# id
# 1       0   @user when a father is dysfunctional and is s...
# 2       0  @user @user thanks for #lyft credit i can't us...
# 3       0                                bihday your majesty
# 4       0  #model   i love u take with u all the time in ...
# 5       0             factsguide: society now    #motivation

# %%
#import BeautifulSoup for data cleaning
from bs4 import BeautifulSoup
#import regexp
import re
#import stopwords from nltk
from nltk.corpus import stopwords

# %%
#use WordNetLemmatizer to lemmatize the words
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize_tweets(raw_review):
    lemmatized_tweet=[]
    raw_review = raw_review.split()
    for w in raw_review:
        word = wordnet_lemmatizer.lemmatize(w)
        lemmatized_tweet.append(word)
    return(" ".join(lemmatized_tweet))
print(lemmatize_tweets("plays in sand and listens"))
# Out:
# play in sand and listens

# %%
#function to segregate only tweets
#defining function separate_tweets() to separate hashtags from main tweet
def separate_tweets(raw_review):
    #changing the whole tweet in lowercase so that hashtags with different cases can match and not be identified as different hashtags
    tweets_only = raw_review.lower()
    #finding all the hashtags
    tweets_only = re.findall("#\w+",tweets_only)
    #returning all hashtags as list
    return(" ".join(tweets_only))
#checking if our function works properly
print(separate_tweets("#i_am_a_good_boy i ama sick # #i_am_tired ##"))
print(separate_tweets("i am going to change everything #i ## #i_am ### @i @@ @# #@   @a@ab@abc #iam#i## #... #I_am_Avinesh"))
#it works :)
# Out:
# #i_am_a_good_boy #i_am_tired
# #i #i_am #iam #i #i_am_avinesh

# %%
#stopwords stored in a set so that we dont have to access the nltk corpus everytimr
stops = set(stopwords.words("english"))
#function to separate all the words in the whole tweet including separation of words from their hashes and mentions
def review_tweets(raw_review):
    review_text = BeautifulSoup(raw_review,"html.parser").get_text()
    #utilising only the letters only from the whole tweet
    #this separates the words from their # and @
    letters_only = re.sub("[^a-zA-Z]"," ",review_text)
    #changing the whole tweet in lowercase so that tweets with different cases can match and not be identified as different tweets
    words = letters_only.lower().split()
    #splitting the whole tweet on the basis of white space
    meaningful_words = [w for w in words if w not in stops]
    return(lemmatize_tweets((" ".join(meaningful_words))))
#checking if our function works properly
print(review_tweets("i am going to change everything #i ## #i_am ### @i @@ @# #@   @a@ab@abc #iam#i## #... plays"))
#it works
# Out:
# going change everything ab abc iam play

# %%
#calculating the total size of the array
num_reviews = train.tweet.size
clean_tweets = []
clean_hashtags = []
for i in range(1,num_reviews):
    clean_tweets.append(review_tweets(train.tweet[i]))
    clean_hashtags.append(separate_tweets(train.tweet[i]))
    if(i%3000 == 0):
        print(i," tweets processed. . . . ")
print("processing completed")
# Out:
# 3000  tweets processed. . . .
# 6000  tweets processed. . . .
# 9000  tweets processed. . . .
# 12000  tweets processed. . . .
# 15000  tweets processed. . . .
# 18000  tweets processed. . . .
# 21000  tweets processed. . . .
# 24000  tweets processed. . . .
# 27000  tweets processed. . . .
# 30000  tweets processed. . . .
# processing completed

# %%
#creating bag of words
from sklearn.feature_extraction.text import CountVectorizer
vectorizer1 = CountVectorizer(analyzer="word",
                            tokenizer=None,
                            preprocessor=None,
                            stop_words=None,
                            max_features=10000)
vectorizer2 = CountVectorizer(analyzer="word",
                            tokenizer=None,
                            preprocessor=None,
                            stop_words=None,
                            max_features=1000)
print("fitting tweets to vectorizer")
tweets_data_features = vectorizer1.fit_transform(clean_tweets)
print("fitting hashtags to vectorizer")
hashtags_data_features = vectorizer2.fit_transform(clean_hashtags)
#changing it to numpy array as it is easy to wrok with them
print("changing all vectors in number form")
tweets_data_features = tweets_data_features.toarray()
hashtag_data_features = hashtags_data_features.toarray()
# Out:
# fitting tweets to vectorizer
# fitting hashtags to vectorizer
# changing all vectors in number form

# %%
print("Tweet bag of words:",tweets_data_features.shape)
print("Hashtag bag of words",hashtag_data_features.shape)
print("Feature names:",vectorizer1.get_feature_names())
# Out:
# Tweet bag of words: (31961, 10000)
# Hashtag bag of words (31961, 1000)
# Feature names: ['aa', 'aaa', 'aap', 'aaron', 'ab', 'abandoned', 'abasel', 'abba', 'abc', 'abe', 'ability', 'abitur', 'able', 'ableg', 'ableism', 'aboion', 'aboutlastnight', 'abrahamhicks', 'abroad', 'absence', 'absolute', 'absolutely', 'abstract', 'abstracta', 'absurd', 'abt', 'abundance', 'abuse', 'abusing', 'abusive', 'ac', 'acab', 'academy', 'acc', 'accent', 'accept', 'acceptable', 'acceptance', 'accepted', 'accepting', 'access', 'accessnetwork', 'accessory', 'accident', 'accidentally', 'accomplishment', 'according', 'account', 'accountable', 'accusation', 'accuse', 'accused', 'ace', 'ache', 'achieve', 'achieved', 'achievement', 'aching', 'acknowledge', 'acne', 'acoustic', 'acquainted', 'acquired', 'acre', 'across', 'act', 'acted', 'acting', 'action', 'active', 'activist', 'activity', 'actor', 'actorslife', 'actress', 'actual', 'actually', 'acu', 'ad', 'adam', 'adamsaleh', 'adapt', 'add', 'added', 'addict', 'addicted', 'addiction', 'adding', 'addition', 'additional', 'address', 'addressing', 'adele', 'adidas', 'admin', 'administration', 'admire', 'admit', 'adopt', 'adopted', 'adopting', 'adorable', 'adrenaline', 'adrienne', 'adult', 'adultery', 'advance', 'advanced', 'advantage', 'adve', 'adveising', 'adventure', 'advice', 'advisor', 'advocate', 'af', 'affair', 'affect', 'affected', 'affective', 'affirmation', 'afford', 'afghan', 'afghanistan', 'afp', 'afraid', 'africa', 'african', 'afro', 'aft', 'aftermath', 'afternoon', 'aftr', 'ag', 'aga', 'age', 'agency', 'agenda', 'agent', 'aggressive', 'aging', 'ago', 'agr', 'agree', 'agreed', 'agreement', 'ah', 'ahead', 'ahfodtour', 'ahh', 'ahhh', 'ahhhh', 'aicle', 'aicles', 'aid', 'aim', 'aint', 'air', 'aired', 'airline', 'airplane', 'airpo', 'aist', 'aists', 'aj', 'ajith', 'ak', 'aka', 'ako', 'akrotiri', 'al', 'ala', 'alabama', 'aladdin', 'alarm', 'alaska', 'albea', 'album', 'alcohol', 'aldub', 'ale', 'alex', 'alhamdulillah', 'ali', 'alice', 'alicia', 'alicrytrinkets', 'alien', 'alive', 'alkalamba', 'allah', 'allahsoil', 'allday', 'alleged', 'allen', 'allergy', 'alley', 'alligator', 'allin', 'alllivesmatter', 'allow', 'allowed', 'allowing', 'allows', 'allsmiles', 'allstars', 'alltheway', 'ally', 'almighty', 'almond', 'almost', 'almostthere', 'almostweekend', 'aloha', 'alohafriday', 'alone', 'along', 'alongside', 'alot', 'alp', 'already', 'alright', 'also', 'alt', 'alternate', 'alternative', 'alternatively', 'although', 'altright', 'altwaystoheal', 'alum', 'alumnus', 'always', 'alyssa', 'amanda', 'amaniknew', 'amarinder', 'amateur', 'amaze', 'amazed', 'amazing', 'amazingly', 'amazingpeople', 'amazon', 'ambassador', 'amber', 'ambiance', 'ambition', 'ambrose', 'amediting', 'ameen', 'amelia', 'amen', 'amendment', 'america', 'americafirst', 'american', 'amid', 'amigo', 'amjoy', 'amo', 'amodu', 'among', 'amongst', 'amor', 'amount', 'amour', 'amp', 'amreading', 'amsterdam', 'amused', 'amwriting', 'amy', 'ana', 'anal', 'analysis', 'analytics', 'anc', 'anchor', 'anchored', 'ancient', 'anderson', 'andrea', 'andreas', 'andrew', 'android', 'andy', 'anf', 'angel', 'angeles', 'angelic', 'anger', 'angie', 'angry', 'angst', 'angus', 'animal', 'animalabuse', 'animaladvocate', 'animalrights', 'animated', 'animation', 'anime', 'ankara', 'anna', 'annaswelshzoo', 'anne', 'annefrank', 'anniversary', 'announce', 'announced', 'announcement', 'announcer', 'announces', 'annoyed', 'annoying', 'annual', 'anon', 'anonymous', 'anorexia', 'another', 'answer', 'answered', 'anthem', 'anthony', 'anti', 'antiaging', 'antiblackness', 'antiracism', 'antisemitism', 'antiwhite', 'anton', 'antonio', 'antonyelchin', 'anxiety', 'anxious', 'anybody', 'anymore', 'anyone', 'anything', 'anytime', 'anyway', 'anyways', 'anywhere', 'anz', 'ap', 'apa', 'apaheid', 'apament', 'apaments', 'apathetic', 'ape', 'apologize', 'apology', 'app', 'appalling', 'apparel', 'apparently', 'appeal', 'appear', 'appearance', 'appearing', 'appears', 'apple', 'appletstag', 'application', 'apply', 'appointment', 'appreciate', 'appreciated', 'appreciati ...

# %%
import numpy as np
tweet_dist = np.sum(tweets_data_features,axis=0)
hashtag_dist = np.sum(hashtag_data_features,axis=0)
for tag,count in zip(vectorizer1.get_feature_names(),tweet_dist):
    print(count," : ",tag)
for tag,count in zip(vectorizer2.get_feature_names(),hashtag_dist):
    print(count," : ",tag)
# Out:
# 2  :  aa
# 3  :  aaa
# 23  :  aap
# 3  :  aaron
# 9  :  ab
# 7  :  abandoned
# 4  :  abasel
# 4  :  abba
# 9  :  abc
# 4  :  abe
# 7  :  ability
# 3  :  abitur
# 73  :  able
# 3  :  ableg
# 5  :  ableism
# 3  :  aboion
# 3  :  aboutlastnight
# 10  :  abrahamhicks
# 4  :  abroad
# 3  :  absence
# 13  :  absolute
# 43  :  absolutely
# 4  :  abstract
# 3  :  abstracta
# 3  :  absurd
# 23  :  abt
# 8  :  abundance
# 17  :  abuse
# 3  :  abusing
# 4  :  abusive
# 5  :  ac
# 3  :  acab
# 7  :  academy
# 7  :  acc
# 7  :  accent
# 29  :  accept
# 10  :  acceptable
# 6  :  acceptance
# 27  :  accepted
# 6  :  accepting
# 13  :  access
# 3  :  accessnetwork
# 13  :  accessory
# 12  :  accident
# 4  :  accidentally
# 3  :  accomplishment
# 10  :  according
# 58  :  account
# 5  :  accountable
# 3  :  accusation
# 3  :  accuse
# 4  :  accused
# 11  :  ace
# 8  :  ache
# 13  :  achieve
# 4  :  achieved
# 8  :  achievement
# 4  :  aching
# 4  :  acknowledge
# 15  :  acne
# 6  :  acoustic
# 3  :  acquainted
# 4  :  acquired
# 3  :  acre
# 22  :  across
# 87  :  act
# 4  :  acted
# 22  :  acting
# 50  :  action
# 12  :  active
# 8  :  activist
# 16  :  activity
# 62  :  actor
# 8  :  actorslife
# 17  :  actress
# 16  :  actual
# 88  :  actually
# 3  :  acu
# 30  :  ad
# 13  :  adam
# 3  :  adamsaleh
# 112  :  adapt
# 45  :  add
# 16  :  added
# 3  :  addict
# 4  :  addicted
# 6  :  addiction
# 9  :  adding
# 8  :  addition
# 3  :  additional
# 14  :  address
# 3  :  addressing
# 11  :  adele
# 8  :  adidas
# 5  :  admin
# 4  :  administration
# 3  :  admire
# 11  :  admit
# 4  :  adopt
# 3  :  adopted
# 3  :  adopting
# 25  :  adorable
# 6  :  adrenaline
# 3  :  adrienne
# 35  :  adult
# 6  :  adultery
# 7  :  advance
# 10  :  advanced
# 8  :  advantage
# 4  :  adve
# 11  :  adveising
# 59  :  adventure
# 27  :  advice
# 3  :  advisor
# 11  :  advocate
# 14  :  af
# 8  :  affair
# 14  :  affect
# 18  :  affected
# 3  :  affective
# 424  :  affirmation
# 11  :  afford
# 6  :  afghan
# 5  :  afghanistan
# 3  :  afp
# 30  :  afraid
# 21  :  africa
# 24  :  african
# 3  :  afro
# 4  :  aft
# 3  :  aftermath
# 66  :  afternoon
# 4  :  aftr
# 10  :  ag
# 4  :  aga
# 50  :  age
# 6  :  agency
# 24  :  agenda
# 7  :  agent
# 3  :  aggressive
# 6  :  aging
# 77  :  ago
# 5  :  agr
# 52  :  agree
# 14  :  agreed
# 3  :  agreement
# 13  :  ah
# 55  :  ahead
# 3  :  ahfodtour
# 4  :  ahh
# 10  :  ahhh
# 9  :  ahhhh
# 20  :  aicle
# 5  :  aicles
# 8  :  aid
# 16  :  aim
# 6  :  aint
# 30  :  air
# 3  :  aired
# 8  :  airline
# 4  :  airplane
# 26  :  airpo
# 41  :  aist
# 12  :  aists
# 4  :  aj
# 3  :  ajith
# 3  :  ak
# 11  :  aka
# 3  :  ako
# 3  :  akrotiri
# 12  :  al
# 3  :  ala
# 10  :  alabama
# 4  :  aladdin
# 16  :  alarm
# 7  :  alaska
# 7  :  albea
# 46  :  album
# 11  :  alcohol
# 12  :  aldub
# 11  :  ale
# 15  :  alex
# 6  :  alhamdulillah
# 19  :  ali
# 4  :  alice
# 3  :  alicia
# 4  :  alicrytrinkets
# 8  :  alien
# 40  :  alive
# 3  :  alkalamba
# 13  :  allah
# 92  :  allahsoil
# 3  :  allday
# 5  :  alleged
# 5  :  allen
# 4  :  allergy
# 5  :  alley
# 28  :  alligator
# 4  :  allin
# 4  :  alllivesmatter
# 32  :  allow
# 16  :  allowed
# 6  :  allowing
# 3  :  allows
# 5  :  allsmiles
# 3  :  allstars
# 3  :  alltheway
# 22  :  ally
# 7  :  almighty
# 3  :  almond
# 98  :  almost
# 3  :  almostthere
# 3  :  almostweekend
# 9  :  aloha
# 4  :  alohafriday
# 107  :  alone
# 55  :  along
# 5  :  alongside
# 5  :  alot
# 5  :  alp
# 126  :  already
# 6  :  alright
# 111  :  also
# 16  :  alt
# 3  :  alternate
# 5  :  alternative
# 7  :  alternatively
# 9  :  although
# 19  :  altright
# 295  :  altwaystoheal
# 4  :  alum
# 7  :  alumnus
# 348  :  always
# 3  :  alyssa
# 4  :  amanda
# 3  :  amaniknew
# 13  :  amarinder
# 10  :  amateur
# 3  :  amaze
# 9  :  amazed
# 332  :  amazing
# 4  :  amazingly
# 3  :  amazingpeople
# 18  :  amazon
# 7  :  ambassador
# 5  :  amber
# 4  :  ambiance
# 4  :  ambition
# 4  :  ambrose
# 3  :  amediting
# 3  :  ameen
# 3  :  amelia
# 24  :  amen
# 8  :  amendment
# 184  :  america
# 3  :  americafirst
# 113  :  american
# 4  :  amid
# 4  :  amigo
# 3  :  amjoy
# 6  :  amo
# 10  :  amodu
# 13  :  among
# 3  :  amongst
# 4  :  amor
# 12  :  amount
# 4  :  amour
# 3  :  amp
# 6  :  amreading
# 18  :  amsterdam
# 3  :  amused
# 26  :  amwriting
# 4  :  amy
# 10  :  ana
# 14  :  anal
# 4  :  analysis
# 34  :  analytics
# 7  :  anc
# 3  :  anchor
# 4  :  anchored
# 7  :  ancient
# 4  :  anderson
# 3  :  andrea
# 4  :  andreas
# 11  :  andrew
# 15  :  android
# 4  :  andy
# 7  :  anf
# 34  :  angel
# 4  :  angeles
# 3  :  angelic
# 36  :  anger
# 3  :  angie
# 205  :  angry
# 4  :  angst
# 3  :  angus
# 94  :  animal
# 3  :  animalabuse
# 3  :  animaladvocate
# 4  :  animalrights
# 3  :  animated
# 18  :  animation
# 34  :  anime
# 5  :  ankara
# 12  :  anna
# 3  :  annaswelshzoo
# 21  :  anne
# 3  :  annefrank
# 71  :  anniversary
# 29  :  announce
# 12  :  announced
# 18  :  announcement
# 3  :  announcer
# 13  :  announces
# 22  :  annoyed
# 7  :  annoying
# 15  :  annual
# 5  :  anon
# 5  :  anonymous
# 3  :  anorexia
# 265  :  another
# 38  :  answer
# 8  :  answered
# 11  :  anthem
# 5  :  anthony
# 41  :  anti
# 4  :  antiaging
# 4  :  antiblackness
# 20  :  antiracism
# 8  :  antisemitism
# 3  :  antiwhite
# 16  :  anton
# 4  :  antonio
# 15  :  antonyelchin
# 79  :  anxiety
# 15  :  anxious
# 15  :  anybody
# 84  :  anymore
# 87  :  anyone
# 100  :  anything
# 3  :  anytime
# 21  :  anyway
# 5  :  anyways
# 21  :  anywhere
# 7  :  anz
# 5  :  ap
# 13  :  apa
# 7  :  apaheid
# 6  :  apament
# 4  :  apaments
# 3  :  apathetic
# 7  :  ape
# 3  :  apologize
# 9  :  apology
# 78  :  app
# 5  :  appalling
# 4  :  apparel
# 32  :  apparently
# 6  :  appeal
# 5  :  appear
# 6  :  appearance
# 4  :  appearing
# 6  :  appears
# 50  :  apple
# 9  :  appletstag
# 6  :  application
# 6  :  apply
# 10  :  appointment
# 28  :  appreciate
# 9  :  appreciated
# 5  :  appreciating
# 13  :  appreciation
# 3  :  approach
# 3  :  approaching
# 4  :  appropriate
# 5  :  approved
# 4  :  approx
# 27  :  apps
# 3  :  appt
# 3  :  appy
# 17  :  april
# 4  :  apt
# 3  :  aquarium
# 8  :  ar
# 10  :  arab
# 4  :  arabian
# 7  :  arabic
# 7  :  archangel
# 6  :  archery
# 6  :  architecture
# 8  :  archive
# 27  :  area
# 4  :  arena
# 3  :  arent
# 3  :  arepa
# 3  :  arff
# 8  :  argentina
# 3  :  argue
# 5  :  arguing
# 16  :  argument
# 3  :  aria
# 6  :  arianagrandedrawing
# 3  :  arin
# 4  :  arizona
# 10  :  arkansas
# 25  :  arm
# 11  :  army
# 195  :  around
# 9  :  arrest
# 4  :  arrested
# 3  :  arresting
# 5  :  arrival
# 23  :  arrive
# 73  :  arrived
# 6  :  arrives
# 8  :  arriving
# 6  :  arsenal
# 5  :  aruba
# 71  :  as
# 5  :  asap
# 11  :  ascot
# 3  :  ased
# 4  :  asf
# 7  :  ash
# 18  :  ashamed
# 13  :  ashiq
# 3  :  ashley
# 11  :  asia
# 46  :  asian
# 6  :  asianladyboy
# 5  :  aside
# 56  :  ask
# 21  :  asked
# 21  :  asking
# 8  :  asks
# 6  :  asleep
# 4  :  aspect
# 11  :  ass
# 21  :  assault
# 6  :  assessment
# 6  :  asset
# 3  :  asshat
# 20  :  asshole
# 4  :  assistant
# 3  :  associate
# 8  :  assume
# 3  :  assuming
# 4  :  assured
# 5  :  astonished
# 4  :  astro
# 27  :  astrologer
# 3  :  asylum
# 16  :  ate
# 3  :  athena
# 11  :  atherapy
# 15  :  athlete
# 3  :  athletics
# 4  :  atl
# 12  :  atlanta
# 3  :  atleast
# 11  :  atm
# 7  :  atmosphere
# 182  :  attack
# 11  :  attacked
# 5  :  attacking
# 19  :  attempt
# 12  :  attend
# 12  :  attending
# 5  :  attends
# 30  :  attention
# 3  :  attest
# 3  :  attic
# 3  :  attica
# 27  :  attitude
# 5  :  attorney
# 5  :  attract
# 3  :  attracted
# 7  :  attraction
# 12  :  attractive
# 9  :  au
# 5  :  auction
# 16  :  aud
# 4  :  audiblechannels
# 7  :  audience
# 7  :  audio
# 3  :  audiojungle
# 4  :  audit
# 8  :  audition
# 4  :  audrey
# 6  :  aug
# 3  :  augmented
# 40  :  august
# 9  :  augusta
# 6  :  aunt
# 3  :  auntie
# 5  :  aupair
# 4  :  aupairlife
# 9  :  auspol
# 7  :  austin
# 35  :  australia
# 8  :  australian
# 19  :  author
# 5  :  authority
# 4  :  autism
# 4  :  autograph
# 4  :  automatic
# 6  :  autumn
# 45  :  available
# 7  :  avenger
# 3  :  avenue
# 11  :  average
# 3  :  aversion
# 3  :  avg
# 4  :  avgeek
# 8  :  avocado
# 13  :  avoid
# 4  :  avon
# 8  :  aw
# 11  :  awaiting
# 3  :  awaits
# 16  :  awake
# 50  :  award
# 3  :  awarded
# 7  :  aware
# 5  :  awareness
# 4  :  awasome
# 172  :  away
# 4  :  awe
# 199  :  awesome
# 6  :  awesomeness
# 12  :  awful
# 9  :  awhile
# 5  :  awkward
# 12  :  awork
# 3  :  aworks
# 3  :  awsome
# 87  :  aww
# 7  :  awww
# 3  :  awwww
# 4  :  aya
# 5  :  aye
# 4  :  az
# 7  :  ba
# 8  :  baba
# 30  :  babe
# 276  :  baby
# 4  :  babyboy
# 3  :  babydaddy
# 13  :  babygirl
# 5  :  bachelorette
# 461  :  back
# 7  :  backed
# 14  :  background
# 4  :  backlash
# 4  :  backpack
# 3  :  backstage
# 4  :  backtoschool
# 3  :  backward
# 5  :  backwards
# 8  :  backyard
# 8  :  bacon
# 174  :  bad
# 8  :  badal
# 4  :  badass
# 5  :  badday
# 7  :  badge
# 5  :  badger
# 14  :  badly
# 5  :  badminton
# 3  :  badweather
# 26  :  bae
# 55  :  bag
# 3  :  bagel
# 3  :  bah
# 5  :  bailey
# 3  :  baiting
# 5  :  bake
# 4  :  baked
# 5  :  baker
# 5  :  bakery
# 7  :  baking
# 6  :  baku
# 3  :  balakrishna
# 30  :  balance
# 8  :  balanced
# 3  :  balancing
# 3  :  balayya
# 11  :  bali
# 42  :  ball
# 3  :  ballad
# 3  :  ballerina
# 3  :  ballet
# 12  :  balloon
# 6  :  baltimore
# 4  :  bam
# 4  :  bambi
# 17  :  ban
# 4  :  banana
# 31  :  band
# 10  :  bang
# 3  :  bangalore
# 8  :  bangkok
# 25  :  bank
# 7  :  bankai
# 6  :  banker
# 4  :  bankruptcy
# 7  :  banned
# 3  :  baptist
# 38  :  bar
# 4  :  barack
# 4  :  barber
# 4  :  barbiets
# 20  :  barcelona
# 4  :  bare
# 12  :  barely
# 4  :  bargain
# 5  :  barn
# 4  :  barney
# 4  :  barrel
# 3  :  barrier
# 4  :  barry
# 13  :  base
# 14  :  baseball
# 18  :  based
# 3  :  basel
# 3  :  basement
# 4  :  bash
# 9  :  bashful
# 5  :  bashing
# 18  :  basic
# 11  :  basically
# 19  :  basis
# 6  :  basket
# 19  :  basketball
# 6  :  bass
# 18  :  bastard
# 3  :  basti
# 6  :  bat
# 14  :  bath
# 9  :  bathroom
# 13  :  batman
# 18  :  battle
# 10  :  battlefield
# 13  :  bay
# 5  :  baylor
# 6  :  bb
# 27  :  bbc
# 3  :  bbcnews
# 6  :  bbh
# 25  :  bbq
# 13  :  bbuk
# 7  :  bbw
# 4  :  bbwlover
# 3  :  bbws
# 41  :  bc
# 4  :  bck
# 8  :  bd
# 52  :  bday
# 4  :  bdayspl
# 207  :  beach
# 8  :  beachbody
# 5  :  beachday
# 7  :  beachlife
# 6  :  bean
# 255  :  bear
# 22  :  beard
# 3  :  bearded
# 8  :  bearer
# 6  :  bearlovestravel
# 5  :  beast
# 46  :  beat
# 9  :  beaten
# 3  :  beating
# 4  :  beatz
# 3  :  beau
# 4  :  beaut
# 524  :  beautiful
# 5  :  beautifulday
# 3  :  beautifull
# 5  :  beautifulsmile
# 137  :  beauty
# 3  :  beaver
# 8  :  became
# 70  :  become
# 18  :  becomes
# 18  :  becoming
# 96  :  bed
# 6  :  bedroom
# 4  :  bedtime
# 21  :  bee
# 4  :  beef
# 7  :  beep
# 63  :  beer
# 4  :  beeroclock
# 3  :  befree
# 3  :  befriending
# 6  :  beg
# 66  :  begin
# 7  :  beginner
# 23  :  beginning
# 4  :  begs
# 10  :  begun
# 35  :  behappy
# 3  :  behaving
# 5  :  behavior
# 50  :  behind
# 4  :  bei
# 8  :  being
# 4  :  beinlife
# 3  :  beirut
# 3  :  bekindtooneanother
# 5  :  bel
# 5  :  belated
# 5  :  belfast
# 4  :  belgian
# 10  :  belgium
# 3  :  belgrade
# 28  :  belief
# 197  :  believe
# 5  :  believed
# 6  :  believing
# 3  :  belive
# 3  :  belize
# 10  :  bell
# 5  :  belly
# 8  :  belong
# 5  :  belongs
# 7  :  beloved
# 3  :  beloy
# 7  :  ben
# 36  :  benefit
# 3  :  bengaluru
# 3  :  benghazi
# 5  :  benidorm
# 5  :  bent
# 7  :  bentley
# 16  :  berlin
# 27  :  bernie
# 6  :  berniesanders
# 5  :  berry
# 7  :  beside
# 5  :  besides
# 3  :  bespoke
# 521  :  best
# 3  :  bestdad
# 4  :  bestday
# 29  :  bestfriend
# 23  :  bestfriends
# 4  :  bestfriendsday
# 27  :  bestie
# 14  :  besties
# 13  :  bestoftheday
# 25  :  bestseller
# 29  :  bet
# 8  :  beta
# 3  :  bethechange
# 4  :  bethesda
# 3  :  betray
# 5  :  betrayal
# 3  :  betrayed
# 3  :  betta
# 197  :  better
# 4  :  betterlife
# 10  :  beutiful
# 7  :  beware
# 3  :  bewitched
# 29  :  beyond
# 10  :  beyou
# 3  :  beyourself
# 23  :  bf
# 29  :  bff
# 6  :  bffs
# 4  :  bhagwantmann
# 3  :  bhakt
# 6  :  bi
# 6  :  bias
# 4  :  biased
# 6  :  bible
# 3  :  biblical
# 5  :  bicycle
# 4  :  biden
# 3  :  bieber
# 3  :  bierce
# 201  :  big
# 3  :  bigapple
# 5  :  bigbang
# 3  :  bigday
# 4  :  bigender
# 20  :  bigger
# 29  :  biggest
# 3  :  biggestfan
# 4  :  bigly
# 37  :  bigot
# 3  :  bigoted
# 26  :  bigotry
# 13  :  bih
# 6  :  bihay
# 874  :  bihday
# 4  :  bihdayboy
# 4  :  bihdaycake
# 23  :  bihdaygirl
# 4  :  bihdaykazuki
# 3  :  bihdaypresent
# 15  :  bihdays
# 6  :  bihdaysway
# 3  :  bihdayweekend
# 3  :  bihdayyourmajesty
# 6  :  biher
# 43  :  bike
# 4  :  biking
# 16  :  bikini
# 31  :  bill
# 8  :  billion
# 9  :  billy
# 9  :  bin
# 3  :  bind
# 152  :  bing
# 16  :  binge
# 6  :  bingewatching
# 16  :  bio
# 3  :  biological
# 108  :  bird
# 12  :  birmingham
# 3  :  biscuit
# 5  :  bisexual
# 4  :  bistro
# 67  :  bit
# 70  :  bitch
# 3  :  bitching
# 14  :  bitcoin
# 12  :  bite
# 18  :  bitter
# 6  :  bittersweet
# 34  :  bjp
# 6  :  bk
# 287  :  black
# 25  :  blackandwhite
# 3  :  blackberry
# 3  :  blackhair
# 4  :  blackheathstandard
# 20  :  blacklivesmatter
# 3  :  blackmaverick
# 5  :  blackpool
# 4  :  blacktwitter
# 3  :  blackwomen
# 3  :  blade
# 3  :  blah
# 28  :  blame
# 10  :  blamed
# 7  :  blaming
# 7  :  blanket
# 18  :  blast
# 6  :  blatant
# 4  :  blatantly
# 7  :  bleed
# 3  :  blend
# 67  :  bless
# 265  :  blessed
# 33  :  blessing
# 3  :  blew
# 6  :  blicqer
# 12  :  blind
# 5  :  blink
# 28  :  bliss
# 4  :  blissful
# 3  :  blk
# 37  :  blm
# 20  :  block
# 22  :  blocked
# 5  :  blocking
# 394  :  blog
# 56  :  blogger
# 11  :  blogging
# 3  :  blogginggals
# 3  :  blogtacular
# 4  :  blond
# 54  :  blonde
# 3  :  blondie
# 22  :  blood
# 3  :  bloodshed
# 17  :  bloody
# 13  :  bloom
# 4  :  blossom
# 10  :  blow
# 14  :  blowing
# 6  :  blowjob
# 5  :  blown
# 3  :  blowoutsbringhappiness
# 4  :  blu
# 105  :  blue
# 3  :  bluedress
# 8  :  blueeyes
# 3  :  bluegrass
# 4  :  bluehand
# 3  :  bluelivesmatter
# 3  :  blueskies
# 9  :  bluesky
# 4  :  blunt
# 3  :  bluntly
# 51  :  blur
# 3  :  bml
# 7  :  bn
# 4  :  bnz
# 6  :  bo
# 3  :  boanoite
# 35  :  board
# 3  :  boarding
# 24  :  boat
# 7  :  boating
# 14  :  bob
# 5  :  bobby
# 3  :  bobo
# 3  :  bobross
# 7  :  bodrum
# 132  :  body
# 3  :  bodycleanse
# 6  :  boe
# 17  :  bogota
# 3  :  bogotadc
# 4  :  bogumday
# 3  :  boheme
# 3  :  boi
# 3  :  boise
# 4  :  boj
# 5  :  bold
# 11  :  bollywood
# 5  :  bolt
# 14  :  bomb
# 3  :  bomber
# 4  :  bombing
# 4  :  bon
# 12  :  bond
# 3  :  bondi
# 11  :  bonding
# 12  :  bone
# 150  :  bong
# 3  :  bonjour
# 3  :  bonnaroo
# 10  :  bonus
# 13  :  boo
# 7  :  boob
# 3  :  boogie
# 177  :  book
# 3  :  bookclub
# 73  :  booked
# 10  :  booking
# 4  :  bookstagram
# 3  :  bookstore
# 3  :  bookworm
# 20  :  boom
# 3  :  boomerang
# 7  :  boost
# 4  :  booster
# 14  :  boot
# 4  :  booth
# 6  :  booty
# 4  :  booze
# 3  :  bopanna
# 4  :  bora
# 4  :  bordeaux
# 4  :  bordercollie
# 32  :  bored
# 25  :  boricua
# 17  :  boring
# 39  :  born
# 3  :  boro
# 31  :  bos
# 4  :  bossbabe
# 3  :  bossmum
# 21  :  boston
# 10  :  bot
# 7  :  bother
# 5  :  bothered
# 3  :  botox
# 25  :  bottle
# 12  :  bottom
# 56  :  bought
# 8  :  bounce
# 27  :  bouncingbaby
# 12  :  bound
# 3  :  boundary
# 3  :  bourbon
# 25  :  bout
# 3  :  boutique
# 5  :  bow
# 5  :  bowl
# 9  :  bowling
# 39  :  box
# 4  :  boxer
# 3  :  boxing
# 228  :  boy
# 17  :  boycott
# 3  :  boycottdelta
# 68  :  boyfriend
# 5  :  brace
# 13  :  bracelet
# 5  :  braid
# 30  :  brain
# 7  :  brainwashed
# 7  :  branch
# 40  :  brand
# 5  :  branding
# 3  :  brandon
# 20  :  brave
# 3  :  bravo
# 8  :  brazil
# 5  :  brazilian
# 11  :  bread
# 84  :  break
# 62  :  breakfast
# 3  :  breakfasting
# 30  :  breaking
# 5  :  breakingnews
# 5  :  breakthrough
# 9  :  breakup
# 6  :  breast
# 11  :  breath
# 10  :  breathe
# 5  :  breathing
# 4  :  breed
# 6  :  breeze
# 3  :  breezy
# 4  :  breitba
# 4  :  bremain
# 4  :  brentwood
# 3  :  bretagne
# 5  :  brew
# 3  :  brewery
# 71  :  brexit
# 5  :  brian
# 4  :  bribe
# 7  :  brick
# 6  :  bridal
# 41  :  bride
# 11  :  bridesmaid
# 5  :  bridetobe
# 20  :  bridge
# 5  :  brief
# 3  :  brigade
# 26  :  bright
# 6  :  brighten
# 18  :  brighton
# 31  :  brilliant
# 63  :  bring
# 12  :  bringing
# 3  :  bringit
# 8  :  bringiton
# 19  :  brings
# 5  :  brisbane
# 7  :  brisk
# 8  :  bristol
# 4  :  brit
# 6  :  britain
# 9  :  brithday
# 17  :  british
# 3  :  brittany
# 33  :  bro
# 3  :  broad
# 5  :  broadcast
# 4  :  broader
# 10  :  broadway
# 8  :  brochure
# 3  :  brock
# 38  :  broke
# 67  :  broken
# 6  :  brokenhea
# 5  :  brokenquotes
# 29  :  broker
# 6  :  bron
# 5  :  brook
# 10  :  brooklyn
# 5  :  bros
# 77  :  brother
# 22  :  brought
# 5  :  brow
# 31  :  brown
# 7  :  browning
# 5  :  browser
# 8  :  bruh
# 16  :  brunch
# 16  :  brunette
# 3  :  brunomars
# 3  :  brush
# 7  :  brussels
# 6  :  brutal
# 6  :  brutality
# 3  :  bsb
# 3  :  bst
# 9  :  bt
# 22  :  bts
# 15  :  btw
# 4  :  bu
# 23  :  bubble
# 7  :  bubbly
# 6  :  buck
# 6  :  bucket
# 4  :  bud
# 20  :  buddy
# 6  :  budget
# 144  :  buffalo
# 5  :  bug
# 23  :  build
# 3  :  builder
# 31  :  building
# 6  :  built
# 3  :  buisness
# 4  :  bulgaria
# 506  :  bull
# 3  :  bulldog
# 5  :  bullet
# 5  :  bullied
# 13  :  bullshit
# 13  :  bully
# 13  :  bullying
# 7  :  bum
# 5  :  bummed
# 6  :  bummer
# 6  :  bump
# 3  :  bun
# 14  :  bunch
# 13  :  bunny
# 13  :  burger
# 5  :  buried
# 12  :  burn
# 3  :  burned
# 9  :  burning
# 7  :  burnt
# 5  :  burst
# 5  :  bury
# 29  :  bus
# 4  :  bush
# 111  :  business
# 3  :  businessoppounity
# 4  :  bust
# 3  :  busty
# 49  :  busy
# 11  :  butt
# 4  :  butter
# 16  :  butterfly
# 3  :  butto
# 12  :  button
# 110  :  buy
# 6  :  buyer
# 20  :  buying
# 4  :  buzz
# 15  :  buzzing
# 4  :  bw
# 28  :  bye
# 4  :  byebye
# 15  :  ca
# 3  :  cab
# 4  :  cabin
# 3  :  cabinet
# 3  :  cable
# 6  :  cactus
# 14  :  cad
# 5  :  caer
# 18  :  cafe
# 3  :  caffe
# 3  :  caffeine
# 8  :  cage
# 63  :  cake
# 3  :  cal
# 4  :  calendar
# 31  :  calgary
# 9  :  cali
# 5  :  calico
# 36  :  california
# 141  :  call
# 60  :  called
# 39  :  calling
# 40  :  calm
# 4  :  calorie
# 4  :  cam
# 4  :  cambridge
# 5  :  camden
# 97  :  came
# 15  :  camera
# 7  :  cameron
# 6  :  camgirl
# 3  :  camgirls
# 3  :  camo
# 47  :  camp
# 44  :  campaign
# 4  :  campaigning
# 11  :  camper
# 3  :  campervan
# 3  :  campfire
# 18  :  camping
# 5  :  campus
# 29  :  canada
# 15  :  canadian
# 6  :  canadiangp
# 4  :  canal
# 11  :  cancel
# 4  :  canceled
# 10  :  cancelled
# 17  :  cancer
# 3  :  cancun
# 3  :  candid
# 30  :  candidate
# 15  :  candle
# 9  :  candy
# 5  :  cannabis
# 6  :  cannon
# 64  :  cannot
# 4  :  cannotwait
# 4  :  canon
# 69  :  cant
# 3  :  cantstopsmiling
# 64  :  cantwait
# 6  :  canvas
# 12  :  caoon
# 4  :  caoons
# 7  :  cap
# 4  :  capable
# 7  :  cape
# 3  :  capetown
# 4  :  capitalism
# 3  :  capitalist
# 6  :  capitalstb
# 3  :  cappuccino
# 4  :  capsule
# 8  :  captain
# 9  :  caption
# 4  :  capture
# 5  :  captured
# 105  :  car
# 65  :  card
# 12  :  cardiff
# 5  :  cardinal
# 5  :  cardio
# 113  :  care
# 9  :  cared
# 27  :  career
# 3  :  carefree
# 5  :  careful
# 3  :  careless
# 6  :  caribbean
# 3  :  caridge
# 9  :  caring
# 18  :  carl
# 5  :  carlos
# 15  :  carlpaladino
# 3  :  carlton
# 3  :  carmineryderrr
# 6  :  carnival
# 4  :  carol
# 4  :  carolina
# 6  :  carpet
# 9  :  carry
# 8  :  carrying
# 5  :  carving
# 5  :  carwash
# 3  :  casa
# 44  :  case
# 7  :  cash
# 7  :  casino
# 4  :  cassie
# 18  :  cast
# 7  :  casting
# 5  :  castle
# 6  :  casual
# 165  :  cat
# 3  :  catalyst
# 23  :  catch
# 10  :  catching
# 5  :  catchup
# 3  :  category
# 3  :  catholic
# 6  :  catlover
# 3  :  catsofinstagram
# 8  :  catsoftwitter
# 3  :  catstagram
# 18  :  caturday
# 5  :  caucasian
# 19  :  caught
# 78  :  cause
# 13  :  caused
# 7  :  causing
# 4  :  cave
# 38  :  cavs
# 3  :  cavsnation
# 3  :  cbc
# 3  :  cbd
# 4  :  cbs
# 9  :  cc
# 3  :  ccot
# 12  :  cd
# 3  :  cdmx
# 3  :  cdn
# 6  :  cdnpoli
# 16  :  ceain
# 6  :  ceainly
# 3  :  cece
# 3  :  cecily
# 5  :  cedarrapids
# 12  :  cedm
# 4  :  ceified
# 3  :  celebrains
# 94  :  celebrate
# 8  :  celebrated
# 5  :  celebrates
# 38  :  celebrating
# 54  :  celebration
# 10  :  celebrity
# 3  :  celebs
# 4  :  celebspot
# 3  :  celinedion
# 6  :  cell
# 3  :  cellphone
# 4  :  celtic
# 5  :  censor
# 3  :  censored
# 14  :  censorship
# 3  :  cent
# 13  :  center
# 10  :  central
# 4  :  centralintelligence
# 4  :  centralpark
# 23  :  centre
# 10  :  century
# 9  :  ceo
# 7  :  cereal
# 11  :  ceremony
# 3  :  cf
# 7  :  ch
# 3  :  cha
# 3  :  chaani
# 9  :  chain
# 22  :  chair
# 4  :  chairman
# 31  :  challenge
# 4  :  challenged
# 3  :  challenging
# 8  :  champ
# 7  :  champagne
# 15  :  champion
# 10  :  championship
# 43  :  chance
# 3  :  chandigarh
# 3  :  chanel
# 218  :  change
# 22  :  changed
# 13  :  changing
# 4  :  chanmi
# 24  :  channel
# 5  :  chant
# 8  :  chaos
# 3  :  chaplin
# 18  :  chapter
# 21  :  character
# 18  :  charge
# 10  :  charging
# 15  :  charity
# 6  :  charles
# 4  :  charleston
# 5  :  charlie
# 6  :  charlotte
# 5  :  charm
# 6  :  charming
# 52  :  chase
# 5  :  chaser
# 3  :  chasing
# 26  :  chat
# 13  :  cheap
# 4  :  cheaper
# 9  :  cheat
# 5  :  cheated
# 7  :  cheating
# 156  :  check
# 13  :  checked
# 7  :  checking
# 6  :  checkout
# 3  :  checkoutmyflyer
# 3  :  checkpoint
# 9  :  cheeky
# 63  :  cheer
# 5  :  cheerful
# 7  :  cheering
# 3  :  cheerleader
# 3  :  cheerup
# 14  :  cheese
# 3  :  cheesecake
# 9  :  cheesy
# 8  :  chef
# 7  :  chelsea
# 3  :  cheltenham
# 3  :  chemical
# 4  :  chemistry
# 4  :  chennai
# 5  :  cherish
# 11  :  cherry
# 4  :  cheryl
# 3  :  chest
# 6  :  chester
# 4  :  chf
# 3  :  chi
# 3  :  chia
# 3  :  chiangmai
# 35  :  chicago
# 25  :  chick
# 20  :  chicken
# 9  :  chief
# 7  :  chihuahua
# 222  :  child
# 5  :  childcare
# 3  :  childfree
# 28  :  childhood
# 8  :  childish
# 3  :  childrensbook
# 9  :  chile
# 62  :  chill
# 7  :  chilled
# 6  :  chillin
# 11  :  chilling
# 3  :  chim
# 25  :  china
# 10  :  chinese
# 3  :  chinup
# 14  :  chip
# 3  :  chipmunk
# 3  :  chipotle
# 29  :  chocolate
# 63  :  choice
# 3  :  choir
# 4  :  choke
# 64  :  choose
# 12  :  choosing
# 7  :  chose
# 15  :  chosen
# 10  :  chris
# 12  :  christ
# 38  :  christian
# 8  :  christianity
# 34  :  christina
# 25  :  christinagrimmie
# 41  :  christmas
# 3  :  christmaseve
# 6  :  chronicpain
# 3  :  chuck
# 5  :  chuffed
# 45  :  church
# 3  :  churchill
# 3  :  ciani
# 4  :  cider
# 3  :  cielo
# 4  :  cigarette
# 3  :  cigs
# 4  :  cincinnati
# 21  :  cinema
# 4  :  cipd
# 11  :  circle
# 6  :  circumstance
# 4  :  circus
# 3  :  cirquedusoleil
# 8  :  citation
# 15  :  citizen
# 254  :  city
# 7  :  civil
# 3  :  civilian
# 4  :  ck
# 31  :  claim
# 4  :  claimed
# 3  :  claiming
# 4  :  clannad
# 5  :  clap
# 3  :  clapton
# 3  :  clare
# 8  :  clarity
# 6  :  clash
# 64  :  class
# 21  :  classic
# 3  :  classical
# 3  :  classified
# 3  :  classism
# 3  :  classmate
# 5  :  classof
# 12  :  classroom
# 8  :  classy
# 3  :  cle
# 38  :  clean
# 5  :  cleaneating
# 5  :  cleaned
# 10  :  cleaning
# 4  :  cleanse
# 24  :  clear
# 4  :  cleared
# 27  :  clearly
# 28  :  cleveland
# 4  :  clever
# 31  :  click
# 5  :  clicking
# 59  :  client
# 4  :  cliff
# 7  :  climate
# 5  :  climatechange
# 246  :  climb
# 4  :  climbing
# 4  :  clinch
# 29  :  clinton
# 8  :  clip
# 12  :  clock
# 71  :  close
# 12  :  closed
# 24  :  closer
# 7  :  closest
# 6  :  closet
# 11  :  closing
# 3  :  cloth
# 29  :  clothes
# 15  :  clothing
# 29  :  cloud
# 5  :  cloudchaser
# 11  :  cloudy
# 13  :  clown
# 68  :  club
# 11  :  clue
# 5  :  clueless
# 4  :  clutch
# 12  :  cm
# 3  :  cmafest
# 5  :  cmon
# 4  :  cmtawards
# 24  :  cnn
# 53  :  co
# 31  :  coach
# 5  :  coachella
# 8  :  coaching
# 5  :  coal
# 8  :  coast
# 4  :  coaster
# 4  :  coat
# 3  :  coc
# 26  :  cock
# 18  :  cocktail
# 3  :  coco
# 5  :  cocoa
# 6  :  coconut
# 4  :  cod
# 17  :  code
# 7  :  coffe
# 104  :  coffee
# 4  :  coin
# 3  :  coke
# 3  :  colbe
# 114  :  cold
# 17  :  coldplay
# 12  :  coldplaywembley
# 3  :  cole
# 4  :  collab
# 8  :  collage
# 4  :  collapse
# 9  :  colleague
# 3  :  collect
# 3  :  collected
# 33  :  collection
# 5  :  collector
# 47  :  college
# 8  :  cologne
# 32  :  colombia
# 6  :  colonialism
# 86  :  color
# 6  :  colorado
# 4  :  colored
# 17  :  colorful
# 4  :  coloring
# 27  :  colour
# 7  :  colourful
# 3  :  columbia
# 3  :  columbus
# 17  :  com
# 8  :  combat
# 5  :  combo
# 437  :  come
# 8  :  comedian
# 31  :  comedy
# 6  :  comeonengland
# 15  :  comfo
# 6  :  comfoable
# 8  :  comfy
# 31  :  comic
# 207  :  coming
# 13  :  comingsoon
# 96  :  comment
# 4  :  commentary
# 4  :  commentator
# 7  :  commenting
# 24  :  commercial
# 5  :  commerzbank
# 5  :  commit
# 8  :  commitment
# 11  :  committed
# 5  :  committee
# 20  :  common
# 4  :  communal
# 4  :  communication
# 4  :  communism
# 5  :  communist
# 59  :  community
# 7  :  commute
# 43  :  company
# 8  :  compare
# 13  :  compassion
# 3  :  compete
# 3  :  competing
# 20  :  competition
# 5  :  compilation
# 13  :  complain
# 3  :  complained
# 8  :  complaining
# 13  :  complaint
# 80  :  complete
# 14  :  completed
# 25  :  completely
# 5  :  complicated
# 3  :  compliment
# 4  :  composed
# 6  :  comprehend
# 3  :  comprehension
# 4  :  comprehensive
# 17  :  computer
# 3  :  comrade
# 16  :  con
# 68  :  conce
# 10  :  concept
# 7  :  concern
# 5  :  concerned
# 9  :  conces
# 6  :  conclusion
# 4  :  condemn
# 3  :  condemned
# 26  :  condemns
# 10  :  condition
# 7  :  conditioning
# 18  :  condolence
# 3  :  condone
# 6  :  conduct
# 4  :  cone
# 114  :  conference
# 5  :  confession
# 3  :  confetti
# 18  :  confidence
# 18  :  confident
# 6  :  confirm
# 10  :  confirmation
# 13  :  confirmed
# 8  :  conflict
# 4  :  confuse
# 42  :  confused
# 3  :  confusion
# 51  :  congrats
# 4  :  congratulate
# 45  :  congratulation
# 21  :  congress
# 3  :  congressional
# 15  :  conjuring
# 4  :  conman
# 10  :  connect
# 10  :  connected
# 4  :  connecticut
# 10  :  connecting
# 8  :  connection
# 3  :  connoisseur
# 4  :  conscious
# 4  :  consequence
# 21  :  conservative
# 7  :  consider
# 7  :  considered
# 9  :  considering
# 3  :  console
# 9  :  conspiracy
# 5  :  constant
# 7  :  constantly
# 5  :  constitution
# 6  :  constitutional
# 7  :  construction
# 15  :  consumer
# 6  :  cont
# 12  :  contact
# 5  :  contagious
# 8  :  contain
# 3  :  container
# 3  :  contempt
# 3  :  contender
# 48  :  content
# 4  :  contented
# 8  :  contest
# 6  :  contestant
# 3  :  contested
# 23  :  continue
# 4  :  continued
# 22  :  continues
# 3  :  continuing
# 10  :  continuous
# 3  :  contour
# 15  :  contract
# 3  :  contribute
# 67  :  control
# 3  :  controlled
# 4  :  controversial
# 6  :  controversy
# 5  :  conveible
# 8  :  convention
# 12  :  conversation
# 4  :  converse
# 4  :  conversion
# 4  :  conviction
# 5  :  convince
# 7  :  convinced
# 3  :  convo
# 13  :  cook
# 3  :  cooked
# 27  :  cooking
# 14  :  cooky
# 202  :  cool
# 5  :  cooler
# 3  :  coolest
# 8  :  coolestlifehack
# 7  :  cooper
# 4  :  coordinate
# 18  :  cop
# 4  :  copaamerica
# 8  :  cope
# 20  :  copy
# 5  :  core
# 3  :  cork
# 8  :  corner
# 4  :  cornwall
# 6  :  corporate
# 11  :  correct
# 4  :  corrected
# 3  :  correctly
# 10  :  corrupt
# 3  :  corrupted
# 20  :  corruption
# 3  :  cosmetic
# 9  :  cosplay
# 17  :  cost
# 3  :  costa
# 4  :  costarica
# 5  :  costume
# 5  :  cotd
# 3  :  cotton
# 23  :  cou
# 5  :  couch
# 4  :  couesy
# 151  :  could
# 7  :  council
# 3  :  councillor
# 37  :  count
# 47  :  countdown
# 29  :  counting
# 134  :  country
# 5  :  county
# 131  :  couple
# 10  :  coupon
# 12  :  courage
# 4  :  courageous
# 60  :  course
# 29  :  cousin
# 3  :  couture
# 3  :  cove
# 42  :  cover
# 8  :  coverage
# 8  :  covered
# 10  :  covering
# 32  :  cow
# 7  :  coward
# 6  :  cowboy
# 3  :  coworker
# 25  :  cox
# 9  :  coybig
# 14  :  coz
# 3  :  cpd
# 7  :  cpi
# 3  :  cptplanespotter
# 9  :  cr
# 4  :  crab
# 13  :  crack
# 6  :  cracked
# 7  :  cracker
# 4  :  cracking
# 23  :  craft
# 4  :  craftbeer
# 3  :  craftfest
# 3  :  craig
# 3  :  crain
# 18  :  crap
# 4  :  crappy
# 7  :  crash
# 3  :  crashed
# 9  :  craving
# 4  :  crayon
# 4  :  craziestpeoples
# 4  :  craziness
# 106  :  crazy
# 30  :  cream
# 3  :  creamy
# 29  :  create
# 15  :  created
# 9  :  creates
# 18  :  creating
# 7  :  creation
# 33  :  creative
# 12  :  creativity
# 6  :  creator
# 6  :  creature
# 3  :  cred
# 3  :  credential
# 5  :  credibility
# 16  :  credit
# 3  :  creed
# 3  :  creep
# 6  :  creepy
# 4  :  cretin
# 19  :  crew
# 5  :  crib
# 14  :  cricket
# 12  :  cried
# 27  :  crime
# 18  :  criminal
# 12  :  crisis
# 6  :  critic
# 6  :  critical
# 8  :  criticism
# 3  :  criticize
# 3  :  cro
# 9  :  croatia
# 6  :  crochet
# 3  :  crony
# 3  :  crook
# 7  :  crooked
# 5  :  crookedhillary
# 19  :  cross
# 11  :  crossed
# 3  :  crossing
# 4  :  crow
# 16  :  crowd
# 3  :  crowdfunding
# 8  :  crown
# 5  :  crude
# 11  :  cruel
# 3  :  crueltyfree
# 9  :  cruise
# 7  :  crush
# 3  :  crushed
# 3  :  crushing
# 4  :  cruz
# 136  :  cry
# 9  :  crystal
# 3  :  cs
# 5  :  cu
# 3  :  cuain
# 5  :  cub
# 4  :  cuba
# 5  :  cube
# 4  :  cuck
# 16  :  cucumber
# 4  :  cud
# 19  :  cuddle
# 3  :  cuddling
# 3  :  cue
# 3  :  cuisine
# 4  :  cult
# 105  :  culture
# 7  :  cum
# 5  :  cunt
# 31  :  cup
# 7  :  cupcake
# 4  :  cuppa
# 7  :  curb
# 4  :  curbyourenthusiasm
# 6  :  cure
# 3  :  curiosity
# 7  :  curious
# 5  :  curly
# 5  :  curlyhair
# 30  :  current
# 15  :  currently
# 15  :  curry
# 6  :  curse
# 4  :  cursedchild
# 3  :  curve
# 5  :  curvy
# 5  :  cushion
# 9  :  custom
# 87  :  customer
# 6  :  customerservice
# 3  :  customised
# 3  :  customized
# 39  :  cut
# 437  :  cute
# 3  :  cutegirl
# 7  :  cuteness
# 14  :  cutest
# 10  :  cutie
# 7  :  cuties
# 6  :  cutting
# 29  :  cuz
# 3  :  cybersecurity
# 7  :  cycle
# 22  :  cycling
# 5  :  cyclist
# 6  :  cyprus
# 5  :  czech
# 44  :  da
# 4  :  dachshund
# 459  :  dad
# 100  :  daddy
# 8  :  daddysgirl
# 3  :  dadsday
# 82  :  daily
# 3  :  dailycatimpression
# 6  :  dairy
# 9  :  daisy
# 8  :  dallas
# 3  :  dam
# 6  :  damage
# 4  :  damaged
# 4  :  damien
# 3  :  dammit
# 72  :  damn
# 4  :  damon
# 7  :  dan
# 3  :  danbury
# 126  :  dance
# 3  :  dancelife
# 16  :  dancer
# 45  :  dancing
# 3  :  dandelion
# 5  :  dang
# 10  :  danger
# 22  :  dangerous
# 6  :  daniel
# 3  :  dank
# 7  :  danny
# 10  :  danske
# 3  :  dapper
# 20  :  dare
# 50  :  dark
# 4  :  darker
# 3  :  darkest
# 4  :  darkknight
# 8  :  darkness
# 10  :  darling
# 3  :  darn
# 13  :  dat
# 25  :  data
# 81  :  date
# 10  :  datenight
# 10  :  dating
# 90  :  daughter
# 6  :  dave
# 3  :  davey
# 20  :  david
# 5  :  davis
# 9  :  dawn
# 2923  :  day
# 12  :  dayoff
# 5  :  daystogo
# 4  :  daze
# 3  :  dazzling
# 20  :  dc
# 3  :  dd
# 35  :  de
# 109  :  dead
# 3  :  deadbydaylight
# 5  :  deadliest
# 3  :  deadline
# 3  :  deadly
# 3  :  deadpool
# 3  :  deaf
# 42  :  deal
# 3  :  dealer
# 7  :  dealing
# 3  :  dean
# 72  :  dear
# 4  :  dearest
# 5  :  dearly
# 80  :  death
# 15  :  debate
# 4  :  debt
# 5  :  debut
# 5  :  dec
# 16  :  decade
# 5  :  deceive
# 4  :  december
# 5  :  decent
# 22  :  decide
# 39  :  decided
# 3  :  decides
# 5  :  deciding
# 35  :  decision
# 6  :  deck
# 3  :  declare
# 7  :  declared
# 4  :  decline
# 3  :  declined
# 14  :  decor
# 4  :  decorating
# 3  :  decoration
# 7  :  decorative
# 6  :  dedicated
# 3  :  dedicating
# 4  :  dedication
# 5  :  dee
# 40  :  deep
# 5  :  deeper
# 3  :  deepest
# 10  :  deeply
# 7  :  defame
# 3  :  default
# 6  :  defeat
# 7  :  defeated
# 5  :  defend
# 3  :  defended
# 3  :  defender
# 9  :  defending
# 12  :  defense
# 4  :  define
# 32  :  definitely
# 15  :  definition
# 21  :  degree
# 6  :  del
# 7  :  delay
# 16  :  delayed
# 3  :  delaying
# 5  :  delegate
# 3  :  delegaterevolt
# 91  :  delete
# 5  :  deleted
# 83  :  deletetweets
# 5  :  deleteyouraccount
# 12  :  delhi
# 3  :  deliberately
# 30  :  delicious
# 4  :  delight
# 19  :  delighted
# 5  :  delightful
# 6  :  deliver
# 17  :  delivered
# 23  :  delivery
# 8  :  delta
# 6  :  delusional
# 6  :  dem
# 12  :  demand
# 3  :  demanding
# 6  :  dementeddonny
# 3  :  demise
# 13  :  demo
# 16  :  democracy
# 15  :  democrat
# 6  :  democratic
# 5  :  democraticpay
# 9  :  dems
# 4  :  den
# 14  :  denial
# 3  :  denied
# 7  :  denim
# 3  :  dennis
# 5  :  denounce
# 4  :  dental
# 4  :  dentist
# 4  :  deny
# 5  :  depament
# 3  :  depaure
# 4  :  depaures
# 3  :  depend
# 5  :  deplorable
# 3  :  deplorables
# 4  :  depp
# 76  :  depressed
# 3  :  depressededit
# 21  :  depressing
# 124  :  depression
# 3  :  dept
# 7  :  depth
# 3  :  derogatory
# 4  :  des
# 3  :  descending
# 17  :  describe
# 9  :  dese
# 37  :  deserve
# 5  :  deserved
# 14  :  deserves
# 70  :  design
# 10  :  designed
# 8  :  designer
# 5  :  designing
# 13  :  desire
# 7  :  desk
# 19  :  desperate
# 3  :  desperately
# 5  :  despise
# 66  :  despite
# 10  :  desse
# 10  :  destination
# 14  :  destiny
# 14  :  destroy
# 11  :  destroyed
# 4  :  destroying
# 7  :  destruction
# 3  :  destructive
# 20  :  detail
# 8  :  determination
# 12  :  determined
# 3  :  detour
# 7  :  detox
# 15  :  detoxdiet
# 7  :  detroit
# 11  :  dev
# 3  :  devastated
# 5  :  devastating
# 3  :  develop
# 8  :  developer
# 4  :  developing
# 84  :  development
# 4  :  device
# 8  :  devil
# 4  :  devops
# 3  :  devoted
# 4  :  dex
# 10  :  dey
# 4  :  dh
# 5  :  dhoni
# 12  :  di
# 4  :  dia
# 4  :  diabetes
# 3  :  diadelpadre
# 7  :  diamond
# 3  :  diaper
# 4  :  diary
# 18  :  dick
# 4  :  dictator
# 3  :  dictatorial
# 6  :  dictionary
# 18  :  didnt
# 51  :  die
# 46  :  died
# 9  :  diego
# 38  :  diet
# 3  :  dieting
# 4  :  diff
# 18  :  difference
# 56  :  different
# 9  :  differently
# 24  :  difficult
# 7  :  dig
# 6  :  digging
# 3  :  digit
# 7  :  digital
# 5  :  dignity
# 3  :  dime
# 3  :  dimple
# 3  :  din
# 5  :  diner
# 7  :  dining
# 64  :  dinner
# 6  :  dinosaur
# 4  :  dip
# 3  :  diploma
# 5  :  dipped
# 3  :  dire
# 179  :  direct
# 4  :  directed
# 3  :  directing
# 13  :  direction
# 6  :  directly
# 15  :  director
# 16  :  dis
# 4  :  disability
# 8  :  disabled
# 4  :  disagrees
# 3  :  disappeared
# 4  :  disappoint
# 55  :  disappointed
# 8  :  disappointing
# 10  :  disappointment
# 8  :  disaster
# 4  :  disbanded
# 4  :  discharge
# 4  :  discipline
# 3  :  disco
# 3  :  discontinued
# 8  :  discount
# 7  :  discover
# 9  :  discovered
# 3  :  discovery
# 12  :  discrimination
# 8  :  discus
# 4  :  discussed
# 4  :  discussing
# 4  :  discussion
# 15  :  disease
# 11  :  disgrace
# 3  :  disgraced
# 10  :  disgraceful
# 4  :  disgust
# 14  :  disgusted
# 34  :  disgusting
# 8  :  dish
# 4  :  dishonest
# 5  :  dislike
# 4  :  dismantle
# 3  :  dismiss
# 73  :  disney
# 9  :  disneygatorattack
# 15  :  disneyland
# 7  :  disorder
# 7  :  display
# 3  :  dispose
# 3  :  disregard
# 7  :  disrespect
# 7  :  disrespectful
# 9  :  dissapointed
# 13  :  distance
# 3  :  distraction
# 6  :  distress
# 3  :  distressed
# 8  :  district
# 7  :  disturbing
# 4  :  ditch
# 3  :  ditching
# 5  :  diva
# 10  :  dive
# 4  :  diver
# 14  :  diversity
# 7  :  divide
# 4  :  diving
# 5  :  division
# 4  :  divisive
# 7  :  divorce
# 5  :  divulga
# 3  :  dixie
# 27  :  diy
# 3  :  diysos
# 61  :  dj
# 6  :  djlife
# 7  :  dl
# 3  :  dlc
# 18  :  dm
# 5  :  dma
# 8  :  dna
# 5  :  dnaquotes
# 6  :  dnc
# 4  :  dnt
# 7  :  doc
# 14  :  doctor
# 3  :  doctorwho
# 12  :  documentary
# 3  :  documented
# 4  :  doe
# 11  :  doesnt
# 288  :  dog
# 5  :  doggie
# 13  :  doggy
# 5  :  doglover
# 10  :  dogsarejoy
# 5  :  dogslife
# 11  :  dogsofinstagram
# 9  :  dogsoftwitter
# 7  :  doin
# 4  :  doj
# 7  :  doll
# 14  :  dollar
# 4  :  dolphin
# 3  :  domain
# 3  :  dome
# 12  :  domestic
# 175  :  dominate
# 44  :  donald
# 13  :  donaldtrump
# 5  :  donate
# 3  :  donated
# 9  :  donation
# 187  :  done
# 7  :  donkey
# 5  :  donor
# 72  :  dont
# 3  :  dontgiveup
# 7  :  donthecon
# 6  :  donut
# 7  :  doodle
# 6  :  doom
# 37  :  door
# 10  :  dope
# 16  :  doplants
# 5  :  dorm
# 5  :  dorset
# 40  :  dory
# 3  :  dosti
# 3  :  dot
# 37  :  double
# 3  :  doublewin
# 22  :  doubt
# 3  :  douchebag
# 3  :  doug
# 3  :  dovish
# 3  :  dowhatyoulove
# 26  :  download
# 4  :  downloaded
# 3  :  downloadfestival
# 3  :  downloading
# 19  :  downtown
# 3  :  doyou
# 6  :  dozen
# 3  :  dp
# 19  :  dr
# 9  :  draft
# 9  :  drag
# 9  :  dragged
# 4  :  draghi
# 14  :  dragon
# 3  :  dragoneducation
# 3  :  dragonfly
# 3  :  drained
# 3  :  draintheswamp
# 7  :  drake
# 5  :  drakeandjosh
# 16  :  drama
# 4  :  dramatic
# 21  :  draw
# 35  :  drawing
# 3  :  drawn
# 5  :  draymond
# 5  :  dread
# 176  :  dream
# 3  :  dreambig
# 9  :  dreamcatcher
# 6  :  dreaming
# 4  :  dreamproject
# 3  :  dreamscometrue
# 3  :  dreamt
# 4  :  dreamteam
# 46  :  dress
# 3  :  dressage
# 8  :  dressed
# 3  :  dresser
# 5  :  dressing
# 3  :  dri
# 3  :  dribbble
# 95  :  drink
# 22  :  drinking
# 28  :  drive
# 4  :  driven
# 29  :  driver
# 23  :  driving
# 3  :  drone
# 28  :  drop
# 12  :  dropped
# 10  :  dropping
# 3  :  drought
# 8  :  drove
# 3  :  drowned
# 25  :  drug
# 4  :  drugaddicts
# 10  :  drum
# 5  :  drumpf
# 21  :  drunk
# 7  :  dry
# 4  :  dt
# 3  :  dtla
# 4  :  dua
# 4  :  dub
# 12  :  dubai
# 15  :  dublin
# 16  :  duck
# 39  :  dude
# 47  :  due
# 3  :  duh
# 5  :  duke
# 4  :  dukhi
# 20  :  dumb
# 3  :  dumbest
# 6  :  dummy
# 7  :  dump
# 5  :  dumptrump
# 3  :  duncan
# 3  :  duo
# 4  :  duper
# 10  :  dust
# 6  :  dustin
# 8  :  dutch
# 10  :  duty
# 6  :  dvd
# 5  :  dvr
# 12  :  dwd
# 5  :  dwp
# 3  :  dxy
# 26  :  dy
# 3  :  dye
# 21  :  dying
# 3  :  dynamic
# 3  :  dysfunction
# 6  :  dystopian
# 6  :  ea
# 7  :  eac
# 6  :  eagle
# 40  :  eah
# 10  :  ear
# 8  :  earlier
# 81  :  early
# 9  :  earn
# 6  :  earned
# 5  :  earp
# 13  :  earring
# 15  :  easier
# 4  :  easiest
# 18  :  easily
# 15  :  east
# 5  :  eastcoast
# 4  :  easter
# 3  :  eastern
# 3  :  eastside
# 62  :  easy
# 60  :  eat
# 5  :  eatclean
# 4  :  eaten
# 34  :  eating
# 4  :  eats
# 9  :  ebay
# 3  :  ebony
# 9  :  ebook
# 3  :  ecb
# 4  :  ece
# 3  :  eclipse
# 4  :  eco
# 3  :  ecommerce
# 6  :  economic
# 11  :  economy
# 7  :  ecstatic
# 3  :  ecuador
# 14  :  ed
# 16  :  edc
# 4  :  eddie
# 4  :  eden
# 5  :  edfringe
# 5  :  edge
# 4  :  edible
# 22  :  edinburgh
# 12  :  edit
# 3  :  edited
# 9  :  editing
# 8  :  edition
# 3  :  editorial
# 6  :  edits
# 27  :  edm
# 4  :  edmonton
# 7  :  educate
# 4  :  educated
# 72  :  education
# 4  :  educational
# 12  :  educationfest
# 3  :  educator
# 3  :  edward
# 3  :  eeek
# 8  :  eek
# 10  :  effect
# 9  :  effective
# 3  :  effectively
# 17  :  effo
# 4  :  effos
# 3  :  eg
# 12  :  egg
# 15  :  ego
# 3  :  egypt
# 8  :  eh
# 4  :  eia
# 19  :  eid
# 6  :  eight
# 41  :  either
# 3  :  ek
# 4  :  el
# 3  :  elder
# 3  :  elderly
# 5  :  elect
# 6  :  elected
# 31  :  election
# 5  :  electric
# 4  :  electricity
# 4  :  electro
# 19  :  electronic
# 8  :  elegant
# 3  :  elegy
# 6  :  element
# 4  :  elementary
# 7  :  elephant
# 4  :  eli
# 3  :  eliminate
# 4  :  elite
# 6  :  elitist
# 6  :  elizabeth
# 5  :  ella
# 3  :  ellen
# 3  :  elliot
# 3  :  elmo
# 3  :  elsa
# 94  :  else
# 5  :  elsewhere
# 35  :  em
# 37  :  email
# 3  :  embarrass
# 5  :  embarrassing
# 14  :  embrace
# 5  :  emea
# 9  :  emergency
# 22  :  emiratis
# 7  :  emma
# 19  :  emo
# 9  :  emoji
# 4  :  emojis
# 53  :  emotion
# 38  :  emotional
# 5  :  emotionally
# 9  :  empathy
# 7  :  empire
# 5  :  employed
# 21  :  employee
# 3  :  employer
# 8  :  employment
# 3  :  empower
# 5  :  empowering
# 4  :  empowerment
# 4  :  emptiness
# 91  :  empty
# 6  :  emtec
# 28  :  en
# 5  :  enchanting
# 4  :  encinitas
# 3  :  encore
# 5  :  encounter
# 5  :  encourage
# 8  :  encouragement
# 184  :  end
# 20  :  ended
# 41  :  ending
# 4  :  endless
# 4  :  endof
# 5  :  endorsed
# 6  :  endorsement
# 4  :  endorses
# 3  :  enduring
# 28  :  enemy
# 5  :  energetic
# 4  :  energized
# 47  :  energy
# 21  :  eng
# 3  :  engage
# 15  :  engaged
# 7  :  engagement
# 4  :  engaging
# 3  :  engine
# 11  :  engineer
# 8  :  engineering
# 58  :  england
# 34  :  english
# 8  :  engrus
# 4  :  engwal
# 252  :  enjoy
# 13  :  enjoyed
# 56  :  enjoying
# 3  :  enjoyinglife
# 11  :  enjoylife
# 4  :  enjoyment
# 3  :  enlightenment
# 114  :  enough
# 3  :  enroute
# 3  :  entangled
# 19  :  enteainment
# 7  :  enter
# 3  :  entered
# 4  :  entering
# 5  :  enthusiasm
# 33  :  entire
# 3  :  entirely
# 4  :  entitled
# 3  :  entitlement
# 3  :  entrance
# 31  :  entrepreneur
# 11  :  entry
# 119  :  environment
# 10  :  environmental
# 5  :  envy
# 14  :  ep
# 7  :  epcot
# 28  :  epic
# 4  :  epidemic
# 81  :  episode
# 13  :  equal
# 26  :  equality
# 4  :  equally
# 4  :  equate
# 3  :  equestrian
# 4  :  equipment
# 5  :  er
# 9  :  era
# 3  :  erased
# 5  :  error
# 15  :  escape
# 3  :  escaped
# 4  :  esco
# 5  :  esp
# 3  :  espa
# 39  :  especially
# 3  :  essence
# 21  :  essential
# 34  :  essentialoils
# 5  :  essex
# 6  :  est
# 4  :  establishment
# 5  :  estate
# 5  :  esteem
# 6  :  et
# 22  :  etc
# 5  :  eternal
# 3  :  eternity
# 4  :  ethnicity
# 4  :  ethnocentrism
# 3  :  etry
# 15  :  etsy
# 19  :  eu
# 3  :  eugenics
# 37  :  eur
# 9  :  euref
# 4  :  eureferendum
# 200  :  euro
# 3  :  eurocup
# 31  :  europe
# 15  :  european
# 3  :  europeangp
# 3  :  europegp
# 7  :  eva
# 4  :  evans
# 22  :  eve
# 344  :  even
# 87  :  evening
# 105  :  event
# 3  :  eventually
# 3  :  eveon
# 267  :  ever
# 3  :  everest
# 234  :  every
# 43  :  everybody
# 73  :  everyday
# 283  :  everyone
# 145  :  everything
# 8  :  everytime
# 27  :  everywhere
# 8  :  evidence
# 29  :  evil
# 3  :  evn
# 5  :  evolution
# 42  :  ex
# 4  :  exact
# 35  :  exactly
# 37  :  exam
# 13  :  example
# 3  :  exc
# 5  :  excellence
# 25  :  excellent
# 20  :  except
# 5  :  excess
# 7  :  exci
# 17  :  excit
# 8  :  excite
# 222  :  excited
# 4  :  excitem
# 3  :  exciteme
# 17  :  excitement
# 52  :  exciting
# 9  :  exclusive
# 24  :  excuse
# 4  :  exec
# 32  :  exercise
# 12  :  exhausted
# 3  :  exhibit
# 8  :  exhibition
# 3  :  exhibitor
# 16  :  exist
# 4  :  existed
# 4  :  existence
# 4  :  exists
# 5  :  exit
# 11  :  exo
# 3  :  exotic
# 4  :  expand
# 49  :  expanse
# 3  :  expansion
# 8  :  expat
# 34  :  expect
# 23  :  expectation
# 20  :  expected
# 4  :  expecting
# 14  :  expensive
# 59  :  experience
# 5  :  experienced
# 6  :  experiencing
# 4  :  experiment
# 11  :  explain
# 3  :  explained
# 6  :  explains
# 4  :  explanation
# 9  :  explore
# 12  :  exploring
# 4  :  explosion
# 3  :  explosive
# 6  :  expo
# 7  :  expose
# 6  :  exposed
# 4  :  exposing
# 12  :  express
# 6  :  expressing
# 7  :  expression
# 5  :  extended
# 5  :  extends
# 4  :  extension
# 5  :  external
# 3  :  extinct
# 4  :  extinction
# 14  :  extra
# 4  :  extraordinaryladyspeaks
# 3  :  extreme
# 15  :  extremely
# 9  :  extremism
# 8  :  extremist
# 3  :  eyan
# 86  :  eye
# 7  :  eyebrow
# 10  :  eyed
# 3  :  eyeing
# 3  :  eyeshadow
# 16  :  fa
# 30  :  fab
# 4  :  fabric
# 25  :  fabulous
# 189  :  face
# 50  :  facebook
# 9  :  faced
# 3  :  facepalm
# 4  :  facetime
# 7  :  facial
# 4  :  facility
# 4  :  facing
# 109  :  fact
# 8  :  factor
# 25  :  factory
# 12  :  factsguide
# 5  :  fade
# 5  :  faded
# 38  :  fail
# 13  :  failed
# 9  :  failing
# 7  :  fails
# 12  :  failure
# 20  :  fair
# 5  :  fairy
# 9  :  fairytail
# 3  :  fairytale
# 42  :  faith
# 4  :  faithful
# 39  :  fake
# 6  :  fakenews
# 3  :  faking
# 55  :  fall
# 3  :  fallacy
# 5  :  fallen
# 13  :  falling
# 4  :  fallout
# 7  :  fallschurch
# 15  :  false
# 19  :  fam
# 4  :  fame
# 4  :  familia
# 5  :  familiar
# 621  :  family
# 4  :  familyfirst
# 6  :  familyfun
# 24  :  familytime
# 4  :  familytrip
# 19  :  famous
# 165  :  fan
# 3  :  fanboy
# 6  :  fancy
# 4  :  fandom
# 7  :  fang
# 3  :  fangirling
# 53  :  fantastic
# 13  :  fantasy
# 94  :  far
# 3  :  farage
# 12  :  faraz
# 5  :  fare
# 7  :  farewell
# 10  :  fargo
# 12  :  farm
# 13  :  farmer
# 6  :  farming
# 8  :  fascinating
# 15  :  fascism
# 16  :  fascist
# 165  :  fashion
# 9  :  fashionblogger
# 3  :  fashiondesign
# 6  :  fashionillustration
# 3  :  fashionista
# 35  :  fast
# 12  :  faster
# 24  :  fasting
# 31  :  fat
# 8  :  fate
# 957  :  father
# 3  :  fatherandson
# 5  :  fatherday
# 3  :  fatherhood
# 3  :  fatherly
# 421  :  fathersday
# 4  :  fathersdaymessage
# 3  :  fathersdayquotes
# 4  :  fatloss
# 6  :  fatty
# 11  :  fault
# 24  :  fav
# 21  :  fave
# 4  :  faves
# 4  :  favor
# 4  :  favored
# 84  :  favorite
# 3  :  favour
# 40  :  favourite
# 3  :  favs
# 18  :  fb
# 12  :  fbi
# 3  :  fblogger
# 3  :  fd
# 6  :  fe
# 56  :  fear
# 3  :  fearful
# 4  :  fearing
# 7  :  fearless
# 3  :  feast
# 6  :  feat
# 3  :  feather
# 9  :  feature
# 10  :  featured
# 5  :  featuring
# 4  :  february
# 26  :  fed
# 3  :  federal
# 7  :  fedup
# 6  :  fee
# 9  :  feed
# 12  :  feedback
# 8  :  feeding
# 452  :  feel
# 15  :  feelgood
# 7  :  feelin
# 322  :  feeling
# 15  :  feelinggood
# 3  :  feelingmyself
# 6  :  feelthebern
# 3  :  felicidad
# 3  :  felicidade
# 27  :  feliz
# 17  :  fell
# 10  :  fella
# 4  :  felling
# 18  :  fellow
# 4  :  felony
# 28  :  felt
# 50  :  female
# 22  :  feminism
# 20  :  feminismiscancer
# 20  :  feminismisterrorism
# 20  :  feminismmuktbharat
# 13  :  feminist
# 4  :  ferguson
# 3  :  ferrari
# 3  :  ferry
# 8  :  fest
# 59  :  festival
# 3  :  feta
# 3  :  fetch
# 3  :  fete
# 5  :  fetish
# 8  :  fever
# 4  :  fewer
# 42  :  ff
# 3  :  fff
# 7  :  ffs
# 4  :  fg
# 5  :  fianc
# 3  :  fiction
# 16  :  field
# 3  :  fiestar
# 9  :  fifa
# 3  :  fifty
# 4  :  figgity
# 43  :  fight
# 10  :  fighter
# 22  :  fighting
# 20  :  figure
# 7  :  figured
# 4  :  fil
# 6  :  file
# 4  :  filibuster
# 12  :  fill
# 31  :  filled
# 4  :  filling
# 73  :  film
# 8  :  filming
# 4  :  filmmaker
# 3  :  filmmaking
# 20  :  filter
# 3  :  filth
# 3  :  filthy
# 3  :  fin
# 78  :  final
# 11  :  finale
# 3  :  finalist
# 342  :  finally
# 4  :  finance
# 8  :  financial
# 308  :  find
# 53  :  finding
# 28  :  findingdory
# 25  :  fine
# 7  :  finest
# 48  :  finger
# 7  :  fingerscrossed
# 36  :  finish
# 68  :  finished
# 12  :  finishing
# 7  :  finland
# 7  :  finn
# 40  :  fire
# 15  :  fired
# 9  :  firefly
# 3  :  fireflymusicfestival
# 5  :  firenze
# 6  :  firework
# 4  :  firing
# 3  :  firm
# 488  :  first
# 4  :  firsttime
# 3  :  firstworldproblems
# 25  :  fish
# 9  :  fishing
# 53  :  fit
# 7  :  fitbit
# 23  :  fitfam
# 5  :  fitmom
# 119  :  fitness
# 10  :  fitnessaddict
# 5  :  fitting
# 25  :  five
# 21  :  fix
# 8  :  fixed
# 3  :  fixit
# 7  :  fixture
# 23  :  fl
# 72  :  flag
# 33  :  flagday
# 6  :  flame
# 4  :  flamingo
# 3  :  flapping
# 8  :  flash
# 3  :  flashback
# 5  :  flashbackfriday
# 3  :  flashing
# 15  :  flat
# 3  :  flavor
# 4  :  flavour
# 5  :  flcrashcorrectors
# 3  :  fleet
# 3  :  flex
# 4  :  flick
# 59  :  flight
# 4  :  flightofalifetime
# 10  :  flip
# 3  :  flipping
# 5  :  floating
# 4  :  flood
# 3  :  flooding
# 13  :  floor
# 6  :  flop
# 5  :  floral
# 5  :  florence
# 72  :  florida
# 5  :  floridashooting
# 3  :  floridian
# 6  :  flourish
# 6  :  flourishing
# 11  :  flow
# 146  :  flower
# 5  :  flowerlove
# 3  :  fluffy
# 51  :  fly
# 5  :  flyer
# 29  :  flying
# 5  :  fm
# 13  :  fml
# 37  :  fo
# 26  :  focus
# 11  :  focused
# 4  :  focusing
# 4  :  folding
# 53  :  folk
# 372  :  follow
# 8  :  followback
# 16  :  followed
# 94  :  follower
# 3  :  followforfollow
# 36  :  following
# 159  :  followme
# 9  :  follows
# 3  :  followusoninstagram
# 3  :  folx
# 4  :  fomc
# 272  :  food
# 4  :  foodblogger
# 34  :  foodie
# 33  :  foodporn
# 4  :  foodstagram
# 20  :  fool
# 5  :  fooled
# 6  :  foolish
# 42  :  foot
# 5  :  footage
# 79  :  football
# 3  :  footballer
# 3  :  footie
# 3  :  footy
# 20  :  force
# 8  :  forced
# 6  :  ford
# 16  :  forecast
# 3  :  forecasted
# 6  :  foreign
# 12  :  forest
# 95  :  forever
# 4  :  foreverliving
# 265  :  forex
# 64  :  forget
# 3  :  forgetting
# 3  :  forgive
# 8  :  forgiveness
# 4  :  forgiver
# 27  :  forgot
# 13  :  forgotten
# 4  :  fork
# 22  :  form
# 3  :  format
# 3  :  formentera
# 12  :  former
# 3  :  forming
# 7  :  forum
# 167  :  forward
# 3  :  foster
# 6  :  fotokuapp
# 12  :  fought
# 6  :  fouh
# 9  :  founate
# 191  :  found
# 3  :  founder
# 3  :  fountain
# 24  :  four
# 18  :  fox
# 3  :  foxnews
# 4  :  fp
# 4  :  fpace
# 18  :  fr
# 7  :  fra
# 4  :  fragile
# 5  :  frame
# 54  :  france
# 3  :  franchise
# 3  :  francisco
# 13  :  frank
# 3  :  frankly
# 4  :  frarou
# 17  :  fraud
# 6  :  freak
# 4  :  freakin
# 13  :  freaking
# 3  :  freckle
# 9  :  fred
# 4  :  freddie
# 287  :  free
# 3  :  freebie
# 67  :  freedom
# 3  :  freelance
# 5  :  freemilo
# 7  :  freespirit
# 4  :  freestyle
# 3  :  freetime
# 3  :  freezer
# 15  :  french
# 3  :  frenchie
# 62  :  fresh
# 3  :  freshman
# 5  :  freshsta
# 8  :  fri
# 540  :  friday
# 55  :  fridayfeeling
# 6  :  fridayfun
# 6  :  fridaynight
# 5  :  fridge
# 759  :  friend
# 19  :  friendly
# 67  :  friendship
# 8  :  fringe
# 3  :  frio
# 21  :  friyay
# 13  :  frm
# 3  :  frnd
# 10  :  frog
# 33  :  front
# 3  :  frontier
# 4  :  frost
# 5  :  frozen
# 21  :  fruit
# 25  :  frustrated
# 9  :  frustrating
# 3  :  frwd
# 11  :  fry
# 15  :  ft
# 120  :  fuck
# 19  :  fucked
# 3  :  fucker
# 9  :  fuckin
# 72  :  fucking
# 4  :  fuckmylife
# 3  :  fuckoff
# 3  :  fucktrump
# 9  :  fuel
# 3  :  fuelled
# 20  :  fuher
# 11  :  fuhered
# 3  :  fulfilled
# 128  :  full
# 3  :  fullest
# 16  :  fully
# 6  :  fuming
# 619  :  fun
# 5  :  fund
# 22  :  funday
# 13  :  funding
# 13  :  fundraising
# 18  :  funeral
# 3  :  funimate
# 4  :  funk
# 3  :  funnehanever
# 220  :  funny
# 3  :  funtime
# 9  :  funtimes
# 3  :  funy
# 4  :  furbabies
# 4  :  furbaby
# 4  :  furious
# 11  :  furniture
# 5  :  furry
# 3  :  fusionmadness
# 3  :  fuss
# 78  :  future
# 4  :  futureofwork
# 3  :  fwis
# 3  :  fyi
# 7  :  ga
# 18  :  gabba
# 3  :  gabby
# 3  :  gadget
# 3  :  gaf
# 3  :  gahbrooks
# 27  :  gain
# 5  :  gained
# 5  :  gal
# 3  :  gala
# 4  :  galaxy
# 12  :  galib
# 12  :  gallery
# 5  :  galway
# 306  :  game
# 3  :  gameday
# 32  :  gamedev
# 15  :  gameofthrones
# 4  :  gameplay
# 29  :  gamer
# 6  :  gamergirl
# 7  :  gamers
# 6  :  gameshow
# 4  :  gamesofthrones
# 25  :  gaming
# 6  :  gandhi
# 20  :  gang
# 4  :  gap
# 9  :  garage
# 5  :  garbage
# 71  :  garden
# 11  :  gardening
# 6  :  gary
# 7  :  gas
# 4  :  gaslighting
# 7  :  gate
# 4  :  gather
# 3  :  gathering
# 21  :  gator
# 49  :  gave
# 5  :  gawa
# 146  :  gay
# 9  :  gayboy
# 3  :  gayguy
# 7  :  gaypride
# 4  :  gazal
# 16  :  gb
# 88  :  gbp
# 6  :  gd
# 3  :  gdp
# 7  :  gear
# 6  :  gearing
# 5  :  gee
# 16  :  geek
# 2  :  geez
# 2  :  geeze
# 16  :  gel
# 7  :  gem
# 12  :  gemini
# 2  :  gemma
# 6  :  gen
# 14  :  gender
# 2  :  gene
# 2  :  genealogy
# 13  :  general
# 2  :  generate
# 36  :  generation
# 2  :  generosity
# 6  :  generous
# 5  :  genetics
# 2  :  geneva
# 9  :  genius
# 17  :  genocide
# 3  :  genre
# 4  :  gent
# 7  :  gentle
# 9  :  gentleman
# 2  :  gentlepassion
# 13  :  genuine
# 8  :  genuinely
# 2  :  geographic
# 3  :  geography
# 3  :  geology
# 3  :  geordie
# 18  :  george
# 5  :  georgia
# 9  :  ger
# 3  :  geranium
# 9  :  german
# 44  :  germany
# 8  :  germanyhetalia
# 2  :  germay
# 2  :  gerona
# 2  :  gerpol
# 1003  :  get
# 3  :  getalife
# 6  :  getaway
# 2  :  getbackup
# 2  :  getfit
# 2  :  gether
# 2  :  getin
# 3  :  getready
# 2  :  getthanked
# 5  :  gettin
# 258  :  getting
# 2  :  gettingdrunk
# 4  :  gettingfit
# 4  :  gettingfitter
# 2  :  gettingready
# 3  :  gettingthere
# 12  :  gewitter
# 14  :  gf
# 2  :  gfe
# 2  :  gfriend
# 2  :  gfs
# 5  :  gg
# 2  :  gh
# 6  :  ghana
# 3  :  ghazal
# 4  :  ghazals
# 12  :  ghost
# 9  :  ghostbusters
# 4  :  ghuggi
# 2  :  gia
# 2  :  gian
# 16  :  giant
# 3  :  giddy
# 39  :  gif
# 119  :  gift
# 2  :  giftcard
# 3  :  gifted
# 7  :  giftideas
# 26  :  gig
# 8  :  giggle
# 2  :  gigi
# 2  :  gilf
# 2  :  gilmore
# 4  :  gimme
# 15  :  gin
# 2  :  ginday
# 3  :  ginger
# 2  :  gingergothitched
# 10  :  giphy
# 650  :  girl
# 2  :  girlboss
# 37  :  girlfriend
# 2  :  girlgamer
# 6  :  girlpower
# 3  :  girlsholiday
# 3  :  girlsnight
# 2  :  girlsnightout
# 2  :  girlsweekend
# 7  :  girltime
# 7  :  girly
# 2  :  girona
# 2  :  giroud
# 2  :  gishwhes
# 2  :  gist
# 187  :  give
# 12  :  giveaway
# 2  :  giveback
# 45  :  given
# 53  :  giving
# 2  :  givingup
# 2  :  gla
# 2  :  glacier
# 55  :  glad
# 6  :  glam
# 7  :  glamorous
# 4  :  glamour
# 6  :  glamping
# 2  :  glamsquad
# 10  :  glasgow
# 44  :  glass
# 2  :  glassesgirl
# 3  :  glasto
# 9  :  glastofest
# 10  :  glastonbury
# 3  :  glastonburyfestival
# 2  :  glazed
# 3  :  glee
# 2  :  glimpse
# 2  :  glinda
# 2  :  glitteattoo
# 10  :  glitter
# 21  :  global
# 2  :  globalists
# 2  :  globalwellnessday
# 5  :  globe
# 2  :  globetrotter
# 9  :  glorious
# 4  :  glory
# 2  :  gloss
# 2  :  gloucestershire
# 5  :  glove
# 3  :  glover
# 7  :  glow
# 6  :  glowing
# 2  :  glte
# 2  :  glute
# 2  :  gluten
# 7  :  glutenfree
# 8  :  gm
# 3  :  gmr
# 2  :  gmschurch
# 4  :  gn
# 2  :  gnwa
# 761  :  go
# 7  :  goa
# 2  :  goaded
# 89  :  goal
# 2  :  goaldigger
# 9  :  goat
# 3  :  goblin
# 264  :  god
# 7  :  godbless
# 2  :  goddamn
# 3  :  goddess
# 2  :  godfather
# 4  :  godisgood
# 2  :  godofwar
# 2  :  gofoe
# 3  :  gogermany
# 2  :  gogirl
# 7  :  goin
# 494  :  going
# 2  :  goinghome
# 5  :  gokaldas
# 2  :  gol
# ...
# 4  :  wud
# 3  :  ww
# 26  :  wwdc
# 14  :  wwe
# 3  :  wwii
# 5  :  www
# 3  :  wynonna
# 3  :  wypipo
# 3  :  xactaccounts
# 15  :  xbox
# 9  :  xboxe
# 8  :  xboxone
# 3  :  xboxones
# 3  :  xc
# 13  :  xd
# 15  :  xenophobia
# 6  :  xenophobic
# 4  :  xian
# 6  :  xmas
# 6  :  xo
# 28  :  xoxo
# 43  :  xx
# 68  :  xxx
# 4  :  xxxx
# 32  :  ya
# 3  :  yaay
# 4  :  yah
# 13  :  yall
# 4  :  yard
# 5  :  yass
# 105  :  yay
# 3  :  yayyy
# 4  :  yayyyy
# 6  :  ye
# 13  :  yea
# 156  :  yeah
# 3  :  yeahhh
# 555  :  year
# 3  :  yearswithinfinite
# 3  :  yeezy
# 3  :  yeezyboost
# 5  :  yeg
# 3  :  yegfood
# 15  :  yelchin
# 5  :  yell
# 3  :  yelling
# 21  :  yellow
# 3  :  yelp
# 5  :  yen
# 19  :  yep
# 206  :  yes
# 3  :  yesallwomen
# 92  :  yesterday
# 141  :  yet
# 3  :  yey
# 3  :  yg
# 4  :  yield
# 4  :  ynwa
# 68  :  yo
# 61  :  yoga
# 3  :  yogalove
# 8  :  yogi
# 19  :  yolo
# 47  :  york
# 4  :  yorkshire
# 141  :  young
# 7  :  younger
# 3  :  youngforever
# 6  :  younique
# 3  :  yousuck
# 36  :  youth
# 5  :  youthday
# 69  :  youtube
# 17  :  youtuber
# 3  :  youtubers
# 4  :  youuu
# 13  :  yoy
# 80  :  yr
# 3  :  yrkkh
# 7  :  yu
# 3  :  yuge
# 3  :  yul
# 31  :  yum
# 47  :  yummy
# 3  :  yumy
# 3  :  yunho
# 12  :  yup
# 3  :  yur
# 11  :  yyc
# 4  :  yyt
# 4  :  zante
# 7  :  zara
# 3  :  zaynmalik
# 7  :  zealand
# 13  :  zelda
# 19  :  zen
# 10  :  zero
# 3  :  zimbabwe
# 4  :  zionazis
# 6  :  zionism
# 3  :  zionist
# 3  :  zip
# 5  :  zombie
# 3  :  zomg
# 13  :  zone
# 8  :  zoo
# 3  :  zoological
# 4  :  zootopia
# 6  :  zoro
# 3  :  zuma
# 3  :  zurich
# 18  :  1gabba
# 80  :  2016
# 15  :  2017
# 21  :  aap
# 10  :  abrahamhicks
# 15  :  acne
# 29  :  actor
# 18  :  adorable
# 20  :  adventure
# 363  :  affirmation
# 60  :  affirmations
# 20  :  aist
# 21  :  all
# 92  :  allahsoil
# 53  :  alone
# 18  :  altright
# 295  :  altwaystoheal
# 11  :  always
# 13  :  amarinder
# 90  :  amazing
# 13  :  amen
# 56  :  america
# 20  :  americans
# 25  :  amwriting
# 32  :  analytics
# 13  :  and
# 14  :  anger
# 16  :  animal
# 33  :  animals
# 15  :  animation
# 29  :  anime
# 17  :  anniversary
# 16  :  annoyed
# 20  :  antiracism
# 15  :  antonyelchin
# 66  :  anxiety
# 13  :  anxious
# 24  :  apple
# 22  :  apps
# 21  :  asian
# 27  :  astrologer
# 11  :  atherapy
# 14  :  aud
# 28  :  australia
# 14  :  author
# 68  :  awesome
# 11  :  aâ
# 30  :  babies
# 80  :  baby
# 10  :  babygirl
# 14  :  bad
# 13  :  balance
# 14  :  barcelona
# 10  :  bbc
# 11  :  bbq
# 13  :  bbuk
# 14  :  bday
# 21  :  be
# 116  :  beach
# 14  :  beard
# 283  :  beautiful
# 78  :  beauty
# 11  :  bed
# 21  :  beer
# 33  :  behappy
# 21  :  believe
# 11  :  berlin
# 43  :  best
# 20  :  bestfriend
# 18  :  bestfriends
# 12  :  bestie
# 11  :  bestoftheday
# 14  :  bestseller
# 12  :  bf
# 18  :  bff
# 14  :  big
# 27  :  bigot
# 22  :  bigotry
# 278  :  bihday
# 22  :  bihdaygirl
# 12  :  bird
# 20  :  birds
# 26  :  bjp
# 70  :  black
# 23  :  blackandwhite
# 19  :  blacklivesmatter
# 12  :  bless
# 200  :  blessed
# 10  :  blessings
# 16  :  bliss
# 29  :  blm
# 346  :  blog
# 35  :  blogger
# 17  :  bloggers
# 28  :  blonde
# 53  :  blue
# 51  :  blur
# 22  :  body
# 17  :  bogota
# 18  :  book
# 15  :  books
# 18  :  bored
# 13  :  boricua
# 12  :  boricuaâ
# 11  :  boston
# 27  :  bouncingbaby
# 50  :  boy
# 14  :  boycott
# 34  :  boyfriend
# 17  :  boys
# 10  :  boyâ
# 26  :  breakfast
# 48  :  brexit
# 25  :  bride
# 13  :  brighton
# 29  :  broken
# 14  :  brother
# 11  :  brunette
# 13  :  buffalo
# 33  :  business
# 36  :  cake
# 30  :  calgary
# 24  :  california
# 14  :  calm
# 17  :  can
# 17  :  canada
# 10  :  candles
# 61  :  cantwait
# 17  :  car
# 15  :  carlpaladino
# 59  :  cat
# 26  :  cats
# 14  :  caturday
# 11  :  cavs
# 12  :  cedm
# 42  :  celebrate
# 21  :  celebration
# 40  :  change
# 11  :  charity
# 16  :  cheers
# 19  :  chicago
# 24  :  child
# 17  :  childhood
# 24  :  children
# 32  :  chill
# 16  :  china
# 14  :  chocolate
# 25  :  christinagrimmie
# 11  :  church
# 13  :  city
# 12  :  cleveland
# 16  :  clouds
# 14  :  cnn
# 54  :  coffee
# 13  :  cold
# 12  :  coldplaywembley
# 25  :  colombia
# 16  :  color
# 15  :  colorful
# 11  :  colors
# 23  :  comedy
# 12  :  comingsoon
# 19  :  conce
# 13  :  confident
# 29  :  confused
# 12  :  congrats
# 10  :  congratulations
# 10  :  congress
# 12  :  content
# 108  :  cool
# 25  :  coolâ
# 11  :  corruption
# 20  :  countdown
# 44  :  couple
# 37  :  crazy
# 14  :  creative
# 10  :  cricket
# 30  :  cry
# 24  :  crying
# 12  :  customer
# 354  :  cute
# 11  :  cuteâ
# 19  :  cycling
# 118  :  dad
# 32  :  daddy
# 44  :  dads
# 58  :  dance
# 16  :  dancing
# 13  :  dark
# 10  :  datenight
# 30  :  daughter
# 254  :  day
# 12  :  dayoff
# 21  :  days
# 10  :  dead
# 10  :  death
# 83  :  deletetweets
# 18  :  delicious
# 63  :  depressed
# 113  :  depression
# 39  :  design
# 15  :  detoxdiet
# 15  :  diet
# 24  :  dinner
# 26  :  disappointed
# 37  :  disney
# 15  :  diy
# 39  :  dj
# 136  :  dog
# 39  :  dogs
# 10  :  dogsarejoy
# 10  :  dogsofinstagram
# 13  :  donaldtrump
# 16  :  doplants
# 25  :  drawing
# 46  :  dream
# 21  :  dreams
# 15  :  dress
# 18  :  drink
# 24  :  drinks
# 12  :  dwd
# 24  :  e3
# 41  :  e32016
# 16  :  eat
# 13  :  edinburgh
# 25  :  edm
# 49  :  education
# 12  :  educationfest
# 13  :  eid
# 14  :  emiratis
# 19  :  emo
# 24  :  emotional
# 19  :  emotions
# 27  :  energy
# 20  :  eng
# 17  :  england
# 110  :  enjoy
# 10  :  enteainment
# 27  :  entrepreneur
# 11  :  epic
# 16  :  equality
# 34  :  essentialoils
# 10  :  etsy
# 33  :  eur
# 129  :  euro2016
# 12  :  europe
# 11  :  euros2016
# 12  :  evening
# 11  :  event
# 21  :  exercise
# 16  :  eyes
# 11  :  f1
# 28  :  f4f
# 17  :  face
# 15  :  facebook
# 20  :  fail
# 24  :  faith
# 272  :  family
# 24  :  familytime
# 10  :  familyâ
# 12  :  faraz
# 11  :  fascism
# 10  :  fascist
# 144  :  fashion
# 129  :  father
# 71  :  fathers
# 333  :  fathersday
# 11  :  fear
# 15  :  feel
# 15  :  feelgood
# 28  :  feeling
# 12  :  feelinggood
# 22  :  feelings
# 18  :  feliz
# 14  :  feminism
# 20  :  feminismiscancer
# 20  :  feminismisterrorism
# 20  :  feminismmuktbharat
# 23  :  festival
# 39  :  ff
# 19  :  film
# 18  :  finally
# 28  :  findingdory
# 22  :  finger
# 11  :  first
# 34  :  fit
# 21  :  fitfam
# 95  :  fitness
# 10  :  fitnessaddict
# 25  :  flag
# 10  :  flagday
# 23  :  flagday2016
# 36  :  florida
# 30  :  flower
# 69  :  flowers
# 13  :  fml
# 112  :  follow
# 13  :  follow4follow
# 14  :  followers
# 153  :  followme
# 47  :  followâ
# 113  :  food
# 26  :  foodie
# 32  :  foodporn
# 25  :  football
# 24  :  forever
# 265  :  forex
# 19  :  france
# 86  :  free
# 19  :  freedom
# 31  :  fresh
# 225  :  friday
# 55  :  fridayfeeling
# 78  :  friend
# 256  :  friends
# 41  :  friendship
# 14  :  friendsâ
# 16  :  friyay
# 18  :  frustrated
# 10  :  fuck
# 434  :  fun
# 10  :  funday
# 11  :  fundraising
# 141  :  funny
# 27  :  funâ
# 31  :  future
# 12  :  galib
# 26  :  game
# 11  :  game7
# 30  :  gamedev
# 14  :  gameofthrones
# 23  :  gamer
# 11  :  games
# 18  :  gaming
# 28  :  garden
# 62  :  gay
# 18  :  gbp
# 13  :  geek
# 16  :  germany
# 12  :  gewitter
# 36  :  gif
# 24  :  gift
# 10  :  gin
# 166  :  girl
# 13  :  girlfriend
# 105  :  girls
# 13  :  girlâ
# 13  :  glasses
# 11  :  go
# 43  :  goals
# 46  :  god
# 298  :  gold
# 12  :  golf
# 73  :  good
# 27  :  goodday
# 11  :  goodlife
# 13  :  goodmood
# 76  :  goodmorning
# 28  :  goodnight
# 10  :  goodread
# 27  :  goodtimes
# 33  :  goodvibes
# 30  :  gop
# 15  :  gorgeous
# 15  :  grace
# 13  :  graduation
# 161  :  grateful
# 31  :  gratitude
# 26  :  great
# 17  :  greece
# 26  :  green
# 16  :  groom
# 11  :  growth
# 15  :  guitar
# 25  :  guns
# 11  :  guy
# 12  :  guys
# 52  :  gym
# 76  :  hair
# 26  :  handmade
# 16  :  handsome
# 235  :  happiness
# 119  :  happy
# 10  :  hard
# 56  :  hate
# 23  :  hatred
# 36  :  hea
# 14  :  heabreaking
# 34  :  heabroken
# 29  :  heal
# 184  :  healing
# 81  :  health
# 571  :  healthy
# 18  :  hello
# 23  :  help
# 11  :  herbalremedies
# 14  :  hillary
# 12  :  hiphop
# 29  :  hispanic
# 18  :  history
# 113  :  holiday
# 20  :  holidays
# 12  :  hollywood
# 123  :  home
# 16  :  homophobic
# 53  :  hope
# 10  :  hopeful
# 51  :  horny
# 12  :  horror
# 107  :  hot
# 10  :  house
# 33  :  hu
# 10  :  hug
# 21  :  humor
# 29  :  humpday
# 29  :  hungry
# 16  :  hype
# 352  :  i_am
# 21  :  ibiza
# 19  :  icecream
# 32  :  idwp
# 29  :  igers
# 11  :  ignorance
# 15  :  illustration
# 10  :  in
# 19  :  india
# 25  :  indiedev
# 17  :  indiegamedev
# 22  :  inlove
# 46  :  inshot
# 106  :  inspiration
# 40  :  inspirational
# 12  :  inspire
# 20  :  inspired
# 16  :  instacool
# 41  :  instadaily
# 13  :  instagay
# 213  :  instagood
# 10  :  instagoodâ
# 44  :  instagram
# 12  :  instahappy
# 45  :  instalike
# 44  :  instamood
# 19  :  instapic
# 10  :  instasize
# 16  :  iphone
# 12  :  iqbal
# 18  :  ireland
# 11  :  isis
# 14  :  islam
# 18  :  israel
# 12  :  it
# 14  :  italy
# 37  :  japan
# 12  :  jewelry
# 29  :  jobs
# 17  :  jobsearch
# 11  :  jocox
# 12  :  joke
# 102  :  joy
# 17  :  joytrain
# 35  :  june
# 13  :  justice
# 11  :  kejriwal
# 14  :  kid
# 59  :  kids
# 13  :  kindness
# 18  :  king
# 50  :  kinky
# 11  :  kiss
# 12  :  kitten
# 22  :  kitty
# 14  :  kkk
# 11  :  kpop
# 30  :  l4l
# 22  :  la
# 10  :  ladies
# 14  :  lasvegas
# 16  :  latepost
# 46  :  laugh
# 12  :  laughter
# 56  :  lawofattraction
# 49  :  leadership
# 15  :  legend
# 12  :  letsgo
# 65  :  lgbt
# 10  :  lgbtq
# 13  :  liar
# 78  :  liberal
# 77  :  libtard
# 406  :  life
# 13  :  lifecoach
# 22  :  lifeisgood
# 79  :  lifestyle
# 24  :  lifeâ
# 14  :  light
# 56  :  lighttherapy
# 74  :  like
# 49  :  like4like
# 19  :  likeforlike
# 16  :  little
# 76  :  live
# 18  :  living
# 23  :  loa
# 56  :  lol
# 72  :  london
# 40  :  lonely
# 10  :  longhair
# 17  :  look
# 13  :  losangeles
# 16  :  loser
# 10  :  loss
# 15  :  lost
# 1542  :  love
# 30  :  loved
# 11  :  loveher
# 14  :  loveisland
# 29  :  loveislove
# 34  :  loveit
# 38  :  lovelife
# 26  :  lovely
# 12  :  lovemylife
# 29  :  lover
# 17  :  loveyou
# 13  :  loveyourself
# 54  :  loveâ
# 16  :  loving
# 10  :  lovinglife
# 24  :  lucky
# 27  :  lunch
# 11  :  luv
# 18  :  luxury
# 22  :  mad
# 12  :  madrid
# 33  :  maga
# 11  :  magic
# 15  :  magnettherapy
# 12  :  make
# 10  :  makes
# 39  :  makeup
# 24  :  malevote
# 33  :  man
# 13  :  marketing
# 15  :  marriage
# 13  :  married
# 13  :  masterkeyexperience
# 336  :  me
# 27  :  media
# 19  :  meditation
# 40  :  melancholy
# 37  :  melancholymusic
# 11  :  meme
# 26  :  memes
# 30  :  memories
# 25  :  men
# 13  :  mentalhealth
# 11  :  mentalillness
# 12  :  mexico
# 28  :  miami
# 38  :  miamiâ
# 12  :  mind
# 23  :  mindfulness
# 75  :  mindset
# 18  :  misogynist
# 22  :  misogyny
# 365  :  model
# 12  :  mohsin
# 24  :  mom
# 28  :  moment
# 17  :  moments
# 64  :  monday
# 18  :  mondaymotivation
# 35  :  money
# 40  :  mood
# 74  :  morning
# 10  :  motivate
# 15  :  motivated
# 166  :  motivation
# 26  :  movie
# 11  :  msnbc
# 274  :  music
# 11  :  musictherapy
# 10  :  musicvideo
# 16  :  muslim
# 31  :  my
# 14  :  mylife
# 18  :  mylove
# 11  :  namaste
# 48  :  nasty
# 15  :  nationalbestfriendsday
# 14  :  natural
# 75  :  nature
# 51  :  naughty
# 12  :  nazi
# 14  :  nba
# 50  :  nbafinals
# 14  :  nerd
# 72  :  nervous
# 16  :  netflix
# 23  :  neverump
# 70  :  new
# 10  :  newlook
# 11  :  newmusic
# 47  :  news
# 10  :  newyear
# 36  :  newyork
# 17  :  next
# 48  :  nice
# 12  :  niece
# 40  :  night
# 13  :  nightout
# 11  :  nike
# 21  :  no
# 40  :  nofilter
# 11  :  not
# 17  :  notmypresident
# 14  :  now
# 18  :  nowplaying
# 11  :  np
# 60  :  nude
# 21  :  nursery
# 11  :  nutrition
# 44  :  nyc
# 40  :  obama
# 20  :  ocean
# 45  :  oitnb
# 27  :  omg
# 31  :  ootd
# 12  :  orangeisthenewblack
# 21  :  organic
# 236  :  orlando
# 15  :  orlandonightclubshooting
# 59  :  orlandoshooting
# 11  :  out
# 11  :  outdoors
# 27  :  pain
# 13  :  painting
# 11  :  pakistan
# 13  :  parenting
# 26  :  paris
# 12  :  park
# 17  :  passion
# 32  :  pathetic
# 93  :  pay
# 176  :  peace
# 19  :  peaceful
# 61  :  people
# 12  :  peppa
# 22  :  perfect
# 16  :  periscope
# 19  :  pet
# 11  :  pets
# 59  :  photo
# 75  :  photography
# 158  :  photooftheday
# 28  :  photos
# 13  :  piano
# 14  :  pic
# 66  :  picoftheday
# 12  :  picofthedayâ
# 14  :  picture
# 10  :  pig
# 11  :  piggies
# 28  :  pink
# 11  :  pissed
# 13  :  pizza
# 20  :  play
# 11  :  podcast
# 15  :  poem
# 18  :  poetry
# 11  :  poland
# 10  :  police
# 99  :  politics
# 23  :  pool
# 12  :  pop
# 11  :  porait
# 57  :  porn
# 874  :  positive
# 30  :  positivevibes
# 32  :  positivity
# 12  :  potus
# 11  :  pougal
# 29  :  pray
# 14  :  prayers
# 11  :  prayersfororlando
# 10  :  prayfoheworld
# 89  :  prayfororlando
# 45  :  pretty
# 23  :  pride
# 84  :  proud
# 16  :  ps4
# 23  :  pulse
# 10  :  pulsenightclub
# 11  :  pulseshooting
# 28  :  punjab
# 14  :  puntohost
# 29  :  puppy
# 14  :  pussy
# 13  :  putinschoice
# 15  :  queen
# 161  :  quote
# 29  :  quoteoftheday
# 100  :  quotes
# 21  :  race
# 10  :  raghuramrajan
# 29  :  rain
# 15  :  rainbow
# 29  :  ramadan
# 15  :  raw
# 19  :  reading
# 20  :  ready
# 12  :  really
# 28  :  red
# 18  :  relationship
# 10  :  relationshipgoals
# 14  :  relationships
# 73  :  relax
# 10  :  relaxed
# 12  :  relaxing
# 10  :  remain
# 10  :  remember
# 28  :  repost
# 13  :  republican
# 13  :  resist
# 15  :  resources
# 19  :  respect
# 10  :  rest
# 85  :  retweet
# 11  :  review
# 11  :  rich
# 93  :  rip
# 46  :  ripchristina
# 31  :  ripchristinagrimmie
# 13  :  roadtrip
# 19  :  rock
# 17  :  romance
# 33  :  run
# 37  :  running
# 19  :  russia
# 70  :  sad
# 14  :  safe
# 11  :  sale
# 91  :  saturday
# 13  :  save
# 11  :  saysomething
# 24  :  scared
# 17  :  scary
# 25  :  school
# 12  :  schwandorfchwandorf
# 12  :  science
# 14  :  scotland
# 41  :  sea
# 22  :  seashepherd
# 15  :  season4
# 13  :  self
# 258  :  selfie
# 12  :  selfieâ
# 13  :  selflove
# 18  :  sex
# 89  :  sexy
# 13  :  shame
# 33  :  share
# 12  :  shocked
# 17  :  shoes
# 13  :  shooting
# 67  :  shop
# 10  :  shopalyssas
# 37  :  shopping
# 14  :  show
# 50  :  shy
# 33  :  sick
# 27  :  sikh
# 14  :  silly
# 299  :  silver
# 10  :  simple
# 16  :  singer
# 29  :  single
# 17  :  sister
# 10  :  sisters
# 74  :  sjw
# 25  :  sky
# 22  :  sleep
# 18  :  sleepy
# 51  :  slut
# 22  :  smh
# 548  :  smile
# 59  :  smiles
# 10  :  smiley
# 31  :  smileâ
# 33  :  smiling
# 34  :  snapchat
# 40  :  snapshot
# 20  :  so
# 38  :  social
# 17  :  socialmedia
# 14  :  sohappy
# 27  :  son
# 13  :  song
# 18  :  sorry
# 11  :  soul
# 11  :  soundcloud
# 16  :  southafrica
# 19  :  spain
# 14  :  spiritual
# 11  :  spo
# 26  :  spos
# 17  :  spring
# 27  :  squad
# 11  :  starbucks
# 27  :  staup
# 11  :  stoked
# 11  :  stop
# 15  :  story
# 10  :  street
# 10  :  strength
# 15  :  stress
# 25  :  strong
# 14  :  studio
# 10  :  stupid
# 51  :  style
# 99  :  success
# 18  :  successful
# 12  :  suicidal
# 19  :  suicide
# 10  :  sukhbir
# 18  :  summeime
# 367  :  summer
# 13  :  summer2016
# 10  :  summerâ
# 171  :  sun
# 156  :  sunday
# 15  :  sundayfunday
# 16  :  sundaymorning
# 51  :  sunny
# 16  :  sunnyday
# 33  :  sunset
# 61  :  sunshine
# 11  :  super
# 13  :  sushi
# 20  :  swag
# 41  :  sweet
# 13  :  swim
# 12  :  swimming
# 10  :  sydney
# 13  :  sâ
# 15  :  tagsforlikes
# 34  :  tampa
# 10  :  tan
# 13  :  tattoo
# 16  :  tb
# 130  :  tbt
# 20  :  tcot
# 27  :  team
# 14  :  teambts
# 12  :  teambtsâ
# 15  :  tears
# 38  :  tech
# 16  :  teen
# 11  :  teeth
# 28  :  temple
# 14  :  terrorism
# 11  :  texas
# 77  :  tgif
# 14  :  thailand
# 491  :  thankful
# 36  :  thanks
# 57  :  thankyou
# 24  :  the
# 12  :  theatre
# 16  :  therapy
# 12  :  theresistance
# 10  :  thoughts
# 20  :  throwback
# 10  :  throwbackthursday
# 55  :  thursday
# 14  :  thursdaythoughts
# 43  :  time
# 11  :  tips
# 45  :  tired
# 15  :  to
# 73  :  today
# 10  :  toddler
# 19  :  together
# 16  :  tokyo
# 10  :  tonight
# 10  :  tonyawards
# 20  :  toptags
# 11  :  toronto
# 18  :  tragedy
# 28  :  tragic
# 17  :  training
# 125  :  travel
# 10  :  traveling
# 17  :  trending
# 26  :  trip
# 26  :  true
# 176  :  trump
# 60  :  truth
# 10  :  tshi
# 32  :  tuesday
# 13  :  turkey
# 11  :  tv
# 15  :  twitch
# 30  :  twitter
# 53  :  udtapunjab
# 11  :  ugh
# 28  :  uk
# 12  :  unbelievable
# 13  :  unhappy
# 24  :  united
# 22  :  university
# 13  :  unleashyourjoy
# 24  :  up
# 17  :  upset
# 10  :  urdu
# 40  :  us
# 59  :  usa
# 23  :  usd
# 12  :  uselections2016
# 47  :  vacation
# 39  :  vegan
# 20  :  vegas
# 12  :  venusexchangeâ
# 16  :  very
# 14  :  vibes
# 34  :  video
# 17  :  view
# 17  :  vine
# 11  :  vintage
# 10  :  violence
# 12  :  vip
# 17  :  vk
# 12  :  vlicobs
# 17  :  vsco
# 13  :  vscocam
# 11  :  waiting
# 11  :  wakeup
# 17  :  walk
# 12  :  warnung
# 12  :  wasi
# 13  :  water
# 15  :  we
# 15  :  weak
# 13  :  weather
# 22  :  web
# 11  :  webcam
# 114  :  wedding
# 14  :  weddingplanning
# 35  :  wednesday
# 21  :  wednesdaywisdom
# 13  :  week
# 265  :  weekend
# 23  :  weightloss
# 14  :  weird
# 11  :  well
# 22  :  wellness
# 46  :  wet
# 12  :  wetter
# 12  :  wetterwarnung
# 14  :  when
# 35  :  white
# 32  :  why
# 11  :  wife
# 21  :  win
# 28  :  wine
# 16  :  winter
# 22  :  wisdom
# 10  :  wishing
# 11  :  with
# 29  :  woman
# 37  :  women
# 11  :  wonderful
# 11  :  words
# 153  :  work
# 16  :  working
# 34  :  workout
# 61  :  world
# 10  :  worldoceansday
# 26  :  wow
# 15  :  writer
# 20  :  writing
# 26  :  wso
# 21  :  wtf
# 14  :  wwdc2016
# 12  :  xenophobia
# 17  :  xoxo
# 48  :  xxx
# 38  :  yay
# 14  :  yellow
# 25  :  yes
# 37  :  yoga
# 17  :  yolo
# 36  :  you
# 53  :  young
# 12  :  your
# 36  :  youtube
# 13  :  youtuber
# 22  :  yum
# 36  :  yummy
# 13  :  zen

# %%
print(type(hashtag_data_features))
print(type(tweets_data_features))
print(hashtag_data_features.shape)
print(tweets_data_features.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (31961, 1000)
# (31961, 10000)

# %%
#joining the two numpy arrays to perform the fitting together
final_data_features = np.concatenate((tweets_data_features,hashtag_data_features),axis=1)
print(final_data_features.shape)

# %%
#applying RandomForest classifier
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=100)
forest = forest.fit((total_data_features),train["label"])

# %%
#read the test file
test = pd.read_csv("test_tweets_anuFYb8.csv")
num_reviews = len(test["tweet"])
clean_tweet_review = []
clean_hash_review = []
print("cleaning and parsing the data . . . .")
for i in range(num_reviews):
    if((i+1)%3000==0):
        print("working on cleaning the test data")
    temp = test["tweet"][i]
    clean_review = review_tweets(test[temp])
    clean_tweet_review.append(clean_review)
    clean_hash = separate_tweets(temp)
    clean_hash_review.append(clean_hash)
tweet_data_features = vectorizer1.transform(clean_tweet_review)
tweet_data_features = test_data_features.toarray()
hash_data_features = vectorizer2.transform(clean_hash_review)
hash_data_features = hash_data_features.toarray()
result = forest.predict(test_data_features)
#create a DataFrame containing the prediction
output = pd.DataFrame(data={"id":test["id"], "label":result})
#output the total result to a .csv file
output.to_csv("predicted.csv",index=False)
